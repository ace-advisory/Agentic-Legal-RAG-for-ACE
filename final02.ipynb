# %%
import os
import json
import time
import random
from typing import List, Dict, Any, Optional, Literal, TypedDict
from uuid import uuid4
from pydantic import BaseModel, Field

from langgraph.graph import StateGraph, END
from langgraph.checkpoint.memory import MemorySaver
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from pinecone import Pinecone
import requests

# %%
# =========================================================
# ENV & CLIENTS (same as previous working version)
# =========================================================
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")
TAVILY_API_KEY = os.getenv("TAVILY_API_KEY")  # optional web agent
USE_TAVILY_DEFAULT = os.getenv("USE_TAVILY", "true").lower() in {"1","true","yes","y"}

if not OPENAI_API_KEY:
    raise RuntimeError("Please set OPENAI_API_KEY")
if not PINECONE_API_KEY:
    raise RuntimeError("Please set PINECONE_API_KEY")

pc = Pinecone(api_key=PINECONE_API_KEY)
emb = OpenAIEmbeddings(model="text-embedding-3-large")
llm_fast = ChatOpenAI(model="gpt-5-mini", temperature=0.2)
llm_reason = ChatOpenAI(model="gpt-5-mini", temperature=0.2)

# %%
# =========================================================
# INDEX MAP (unchanged)
# =========================================================
INDEXES = {
    "acts": "act-agentic-chunking",
    "rules": "rules-agentic-chunking",
    "sro": "sro-agentic-chunking",
    "ordinances": "ordinance-agentic-chunking",
}

# %%
# =========================================================
# DATA MODELS (adds 'web' to Hit.index and hits dict)
# =========================================================
class Hit(BaseModel):
    index: Literal["acts","rules","sro","ordinances","web"]
    id: str
    score: float
    text: str
    metadata: Dict[str, Any] = Field(default_factory=dict)

class RetrievalBundle(BaseModel):
    query: str
    law_name: Optional[str] = None
    law_year: Optional[str] = None
    hierarchy: Dict[str, Optional[str]] = Field(default_factory=lambda: {
        "part": None, "chapter": None, "section": None, "subsection": None, "clause": None
    })
    hits: Dict[str, List[Hit]] = Field(default_factory=lambda: {
        "acts": [], "rules": [], "sro": [], "ordinances": [], "web": []
    })
    merged: List[Hit] = Field(default_factory=list)
    latest_verification: Dict[str, Any] = Field(default_factory=dict)
    final_answer: Optional[str] = None
    citations: List[Dict[str, Any]] = Field(default_factory=list)
    use_web: bool = USE_TAVILY_DEFAULT
    web_query: Optional[str] = None

# %%
# =========================================================
# HELPERS (as before)
# =========================================================

def _norm(s: Optional[str]) -> Optional[str]:
    if not s: return s
    return " ".join(str(s).strip().split())


def _build_queries(b: RetrievalBundle) -> List[str]:
    q = [b.query]
    if b.law_name:
        q += [
            f"{b.law_name} {b.law_year or ''}".strip(),
            f"{b.law_name} consolidated version latest amendment",
            f"{b.law_name} Rules Regulations",
            f"{b.law_name} SRO latest supersession",
        ]
    for k in ["part","chapter","section","subsection","clause"]:
        if b.hierarchy.get(k):
            q.append(f"{b.law_name or ''} {k} {b.hierarchy[k]}".strip())
    out, seen = [], set()
    for s in q:
        s = _norm(s)
        if s and s.lower() not in seen:
            out.append(s); seen.add(s.lower())
    return out


def _embed(q: str) -> List[float]:
    return emb.embed_query(q)


def _pc_query(index_name: str, vec: List[float], top_k: int = 10) -> List[Dict[str, Any]]:
    index = pc.Index(index_name)
    res = index.query(vector=vec, top_k=top_k, include_metadata=True)
    return res.get("matches", [])

# %%
# =========================================================
# RETRIEVAL (Pinecone) — same logic
# =========================================================

def retrieve_per_index(bundle: RetrievalBundle, top_k: int = 10) -> RetrievalBundle:
    queries = _build_queries(bundle)
    all_hits = {"acts": [], "rules": [], "sro": [], "ordinances": [], "web": bundle.hits.get("web", [])}
    for q in queries:
        vec = _embed(q)
        for tag, idx in INDEXES.items():
            try:
                res = _pc_query(idx, vec, top_k=top_k)
                for m in res:
                    md = m.get("metadata",{}) or {}
                    txt = md.get("page_content") or md.get("text") or ""
                    h = Hit(index=tag, id=m["id"], score=m.get("score",0.0), text=txt, metadata={**md, "_query": q, "_index_name": idx})
                    all_hits[tag].append(h)
            except Exception as e:
                print(f"[WARN] Retrieval failed for {idx}: {e}")
    bundle.hits = all_hits
    return bundle

# %%
# =========================================================
# WEB SEARCH (Tavily) — Lawyer-Style staged queries
# =========================================================
TAVILY_ENDPOINT = "https://api.tavily.com/search"

ALLOWED_DOMAINS_DEFAULT = [
    "bdlaws.minlaw.gov.bd",
    "nbr.gov.bd",
    "mof.gov.bd",
    "dpp.gov.bd",
    "cabinet.gov.bd",
    "bangladesh.gov.bd",
]
_extra_domains = os.getenv("TAVILY_ALLOWED_DOMAINS", "").strip()
if _extra_domains:
    for d in _extra_domains.split(","):
        d = d.strip()
        if d and d not in ALLOWED_DOMAINS_DEFAULT:
            ALLOWED_DOMAINS_DEFAULT.append(d)

_BN2EN = str.maketrans("০১২৩৪৫৬৭৮৯", "0123456789")
_EN2BN = str.maketrans("0123456789", "০১২৩৪৫৬৭৮৯")

def to_en(s: str) -> str: return (s or "").translate(_BN2EN)

def to_bn(s: str) -> str: return (s or "").translate(_EN2BN)

KEYWORDS_TRIGGER = ["latest","recent","সর্বশেষ","গেজেট","gazette","SRO","s.r.o","amend","amendment","updated","supersede"]


def should_web_search(bundle: RetrievalBundle) -> bool:
    if not TAVILY_API_KEY: return False
    if not bundle.use_web: return False
    q = (bundle.web_query or bundle.query or "").lower()
    few_hits = sum(len(v) for k,v in bundle.hits.items() if k != "web") < 6
    kw = any(k in q for k in KEYWORDS_TRIGGER)
    return few_hits or kw


def build_web_queries(bundle: RetrievalBundle) -> List[Dict[str, Any]]:
    q = bundle.query or ""
    law = bundle.law_name or ""
    year = (bundle.law_year or "").strip()
    sec = bundle.hierarchy.get("section") or ""
    subsec = bundle.hierarchy.get("subsection") or ""
    clause = bundle.hierarchy.get("clause") or ""

    sec_en, subsec_en, clause_en = to_en(sec), to_en(subsec), to_en(clause)
    sec_bn, subsec_bn, clause_bn = to_bn(sec_en), to_bn(subsec_en), to_bn(clause_en)

    s1 = [
        {"stage":1, "q": f"{law} {year} official gazette pdf", "domains": ALLOWED_DOMAINS_DEFAULT},
        {"stage":1, "q": f"{law} {year} act text site:bdlaws.minlaw.gov.bd", "domains":["bdlaws.minlaw.gov.bd"]},
    ]

    s2 = []
    if sec or subsec or clause:
        base = f"{law} {year} Section {sec_en}{subsec_en}{clause_en}".strip()
        base_bn = f"{law} {year} ধারা {sec_bn}{subsec_bn}{clause_bn}".strip()
        s2 += [
            {"stage":2, "q": base + " site:bdlaws.minlaw.gov.bd", "domains":["bdlaws.minlaw.gov.bd"]},
            {"stage":2, "q": base_bn + " site:bdlaws.minlaw.gov.bd", "domains":["bdlaws.minlaw.gov.bd"]},
        ]

    s3 = [
        {"stage":3, "q": f"{law} {year} Rules pdf gazette", "domains":["nbr.gov.bd","dpp.gov.bd","mof.gov.bd","bangladesh.gov.bd"]},
        {"stage":3, "q": f"Income Tax Rules {to_en(year) or '2023'} pdf site:nbr.gov.bd", "domains":["nbr.gov.bd"]},
    ]

    s4 = [
        {"stage":4, "q": f"SRO {sec_en or q} {year} site:nbr.gov.bd", "domains":["nbr.gov.bd"]},
        {"stage":4, "q": f"S.R.O {sec_en or q} {year} gazette pdf", "domains":["nbr.gov.bd","dpp.gov.bd","mof.gov.bd"]},
    ]

    s5 = [
        {"stage":5, "q": f"{law} {year} consolidated updated latest amendment site:bdlaws.minlaw.gov.bd", "domains":["bdlaws.minlaw.gov.bd"]},
        {"stage":5, "q": f"{law} {year} latest SRO supersedes site:nbr.gov.bd", "domains":["nbr.gov.bd"]},
        {"stage":5, "q": f"{law} {year} latest gazette publication", "domains":["dpp.gov.bd","nbr.gov.bd","mof.gov.bd","cabinet.gov.bd"]},
    ]

    fallback = [{"stage":9, "q": q, "domains": ALLOWED_DOMAINS_DEFAULT}]

    queries = s1 + s2 + s3 + s4 + s5 + fallback
    out = []
    for spec in queries:
        qq = " ".join(x for x in spec["q"].split() if x)
        if qq:
            out.append({"stage": spec["stage"], "q": qq, "domains": spec["domains"]})
    return out


def tavily_search(query: str, max_results: int = 5, domains: Optional[List[str]] = None) -> List[Dict[str, Any]]:
    headers = {"Content-Type": "application/json"}
    payload = {
        "api_key": TAVILY_API_KEY,
        "query": query,
        "search_depth": "basic",
        "max_results": max_results,
        "include_answer": False,
        "include_images": False,
        "include_domains": domains or ALLOWED_DOMAINS_DEFAULT,
        "exclude_domains": [],
    }
    for attempt in range(3):
        try:
            r = requests.post("https://api.tavily.com/search", headers=headers, data=json.dumps(payload), timeout=15)
            if r.status_code == 200:
                return r.json().get("results", [])
            time.sleep(1.2 * (2 ** attempt) + random.random())
        except Exception:
            time.sleep(1.2 * (2 ** attempt) + random.random())
    return []


def web_search_node(state: Dict[str, Any]) -> Dict[str, Any]:
    bundle: RetrievalBundle = state["bundle"]
    if not should_web_search(bundle):
        return state

    specs = build_web_queries(bundle)
    seen_urls = set()
    web_hits: List[Hit] = []

    for spec in specs:
        if len(web_hits) >= 10:
            break
        results = tavily_search(spec["q"], max_results=4, domains=spec.get("domains"))
        for i, r in enumerate(results):
            url = r.get("url")
            if not url or url in seen_urls:
                continue
            seen_urls.add(url)
            title = r.get("title")
            snippet = r.get("content") or r.get("snippet") or ""
            score = 0.4 + (6 - min(spec["stage"], 6)) * 0.08 + (4 - min(i, 4)) * 0.02
            web_hits.append(
                Hit(
                    index="web",
                    id=url,
                    score=score,
                    text=snippet[:1800],
                    metadata={"title": title, "source_url": url, "_query": spec["q"], "provider": "tavily", "stage": spec["stage"]},
                )
            )

    bundle.hits.setdefault("web", [])
    bundle.hits["web"].extend(web_hits)
    state["bundle"] = bundle
    return state

# %%
# =========================================================
# RERANK (unchanged logic)
# =========================================================

def _l2r_rerank(hits: List[Hit]) -> List[Hit]:
    if not hits: return []
    items = "\n\n".join([f"[{i}] (index={h.index}, score={h.score:.4f})\nMETA={h.metadata}\nTEXT={h.text[:1000]}" for i,h in enumerate(hits)])
    prompt = ChatPromptTemplate.from_messages([
        ("system", "Score each item 0-100 for answering the legal query. Prefer exact law+year, hierarchy match, latest SRO/amendments, official Gazette sources. Web is supportive only. I want a clean well organized response. NO '#' sign in the response"),
        ("human", "User query: {query}\n\nItems:\n{items}\n\nReturn JSON: {\"rank\":[{\"i\":<int>,\"score\":<int>}]}" )
    ])
    try:
        resp = (prompt | llm_fast | StrOutputParser()).invoke({"query": hits[0].metadata.get("_query",""), "items": items})
        j = json.loads(resp)
        order = {e.get("i"): e.get("score", 0) for e in j.get("rank",[]) if isinstance(e.get("i"), int)}
        ranked = sorted(range(len(hits)), key=lambda i: order.get(i, 0), reverse=True)
        return [hits[i] for i in ranked]
    except Exception:
        return sorted(hits, key=lambda h: h.score, reverse=True)


def merge_and_rerank(bundle: RetrievalBundle) -> RetrievalBundle:
    merged = []
    for lst in bundle.hits.values():
        merged.extend(lst)
    seen = set(); uniq = []
    for h in merged:
        key = (h.index, h.id)
        if key in seen: continue
        seen.add(key); uniq.append(h)
    bundle.merged = _l2r_rerank(uniq)[:20]
    return bundle

# %%
# =========================================================
# ENTITY RESOLVER (unchanged)
# =========================================================
resolver_prompt = ChatPromptTemplate.from_messages([
    ("system", "Extract law research entities from the user query in JSON."),
    ("human", "User query:\n{query}\n\nReturn JSON with law_name, law_year, hierarchy {{part, chapter, section, subsection, clause}}")
])


def resolve_entities(bundle: RetrievalBundle) -> RetrievalBundle:
    resp = (resolver_prompt | ChatOpenAI(model="gpt-4o-mini", temperature=0.0) | StrOutputParser()).invoke({"query": bundle.query})
    try:
        j = json.loads(resp)
    except Exception:
        j = {}
    bundle.law_name = _norm(j.get("law_name"))
    bundle.law_year = _norm(j.get("law_year"))
    if "hierarchy" in j and isinstance(j["hierarchy"], dict):
        for k,v in j["hierarchy"].items():
            bundle.hierarchy[k] = _norm(v)
    return bundle

# %%
# =========================================================
# VERIFICATION (unchanged prompt, can see web items too)
# =========================================================
ver_prompt = ChatPromptTemplate.from_messages([
    ("system", "Verify latest legal effect given retrieved snippets and metadata from Acts/Rules/SROs; web sources are supportive unless linking to primary gazettes."),
    ("human", "Query:\n{query}\nItems:\n{items}\nReturn JSON with latest_sro_ids, consolidated_effect_asof, notes, reasoning")
])

def verify_amendments(bundle: RetrievalBundle) -> RetrievalBundle:
    if not bundle.merged:
        bundle.latest_verification = {"latest_sro_ids": [], "reasoning": "no hits", "consolidated_effect_asof": None, "notes":[]}
        return bundle
    items = "\n\n".join([f"[{i}] index={h.index} id={h.id} score={h.score:.4f}\nMETA={h.metadata}\nTEXT={h.text[:1200]}" for i,h in enumerate(bundle.merged[:18])])
    resp = (ver_prompt | llm_reason | StrOutputParser()).invoke({"query": bundle.query, "items": items})
    try:
        j = json.loads(resp)
    except Exception:
        j = {"latest_sro_ids": [], "reasoning": "parse_error", "consolidated_effect_asof": None, "notes":[]}
    bundle.latest_verification = j
    return bundle

# %%
# =========================================================
# ANSWER (unchanged + includes web citations url)
# =========================================================
answer_prompt = ChatPromptTemplate.from_messages([
    ("system", "Bilingual Bangla+English legal assistant. Cite multiple sources and reflect latest SROs."),
    ("human", "Query:\n{query}\nCtx:\n{ctx}\nVer:\n{ver}\nWrite final answer with Bangla bullets, legal path, latest status, citations (include url if web). Be friendly and professional. Answer must be in great details. Initially explain the problem by providing proper definition with references and sources")
])

def synthesize(bundle: RetrievalBundle) -> RetrievalBundle:
    ctx = "\n\n".join([f"[{i}] index={h.index} id={h.id}\nMETA={h.metadata}\nEXTRACT={h.text[:800]}" for i,h in enumerate(bundle.merged[:12])])
    ver = bundle.latest_verification
    resp = (answer_prompt | llm_reason | StrOutputParser()).invoke({"query": bundle.query, "ctx": ctx or "No context.", "ver": ver})
    bundle.final_answer = resp
    cits = []
    for h in bundle.merged[:12]:
        cits.append({
            "index": h.index,
            "id": h.id,
            "title": h.metadata.get("title") or h.metadata.get("rules_name") or h.metadata.get("act_name") or h.metadata.get("sro_title"),
            "date": h.metadata.get("sro_date") or h.metadata.get("date") or h.metadata.get("gazette_date"),
            "score": h.score,
            "url": h.metadata.get("source_url"),
        })
    bundle.citations = cits
    return bundle

# %%
# =========================================================
# LANGGRAPH WIRING (add web node between retrieve and merge)
# =========================================================
class GraphState(TypedDict):
    bundle: RetrievalBundle

def _start(state: GraphState) -> GraphState: return state

def _entities(state: GraphState) -> GraphState:
    state["bundle"] = resolve_entities(state["bundle"]); return state

def _retrieve(state: GraphState) -> GraphState:
    state["bundle"] = retrieve_per_index(state["bundle"], top_k=6); return state

def _web(state: GraphState) -> GraphState:
    return web_search_node(state)

def _merge(state: GraphState) -> GraphState:
    state["bundle"] = merge_and_rerank(state["bundle"]); return state

def _verify(state: GraphState) -> GraphState:
    state["bundle"] = verify_amendments(state["bundle"]); return state

def _answer(state: GraphState) -> GraphState:
    state["bundle"] = synthesize(state["bundle"]); return state

graph = StateGraph(GraphState)
graph.add_node("start", _start)
graph.add_node("entities", _entities)
graph.add_node("retrieve", _retrieve)
graph.add_node("web", _web)
graph.add_node("merge", _merge)
graph.add_node("verify", _verify)
graph.add_node("answer", _answer)

graph.set_entry_point("start")
graph.add_edge("start","entities")
graph.add_edge("entities","retrieve")
graph.add_edge("retrieve","web")
graph.add_edge("web","merge")
graph.add_edge("merge","verify")
graph.add_edge("verify","answer")
graph.add_edge("answer", END)

memory = MemorySaver()
app = graph.compile(checkpointer=memory)

# Safe ensure for out-of-order exec

def _ensure_app():
    global app, memory
    try:
        _ = app
    except NameError:
        memory = MemorySaver()
        app = graph.compile(checkpointer=memory)
    return app

# %%
# =========================================================
# PUBLIC RUNNER (same signature + web controls)
# =========================================================

def run_legal_query(user_query: str, law_name: Optional[str]=None, law_year: Optional[str]=None, hierarchy: Optional[Dict[str, Optional[str]]]=None, thread_id: Optional[str]=None, use_web: Optional[bool]=None, web_query: Optional[str]=None) -> RetrievalBundle:
    b = RetrievalBundle(query=user_query)
    if law_name: b.law_name = law_name
    if law_year: b.law_year = law_year
    if hierarchy: b.hierarchy.update(hierarchy)
    if use_web is not None: b.use_web = bool(use_web)
    if web_query: b.web_query = web_query
    cfg = {"configurable": {"thread_id": thread_id or str(uuid4())}}
    _ensure_app()
    out = app.invoke({"bundle": b}, config=cfg)
    return out["bundle"]

# %%
out = run_legal_query(
    "আয়কর আইন, ২০২৩ এর ধারা ৫২(১)(ক) অনুযায়ী TDS এর Rules এবং সর্বশেষ SRO কী?",
    use_web=True
)
print(out.final_answer)
print(out.citations)
# Out:
# আদরণীয় ব্যবহারকারী,
#
# আপনার প্রশ্ন অনুযায়ী, আয়কর আইন, ২০২৩ এর ধারা ৫২(১)(ক) অনুযায়ী TDS (উৎসে কর) সম্পর্কিত বিধিমালা এবং সর্বশেষ সংশোধনী (SRO) সম্পর্কে বিস্তারিত তথ্য নিচে উপস্থাপন করা হলো।
#
# ---
#
# ### ১. আইনি ভিত্তি ও বিধিমালা
#
# - **আইন:** আয়কর আইন, ২০২৩ (২০২৩ সনের ১২ নং আইন)
# - **ধারা:** ধারা ৫২(১)(ক) অনুযায়ী উৎসে কর (TDS) ধার্য ও সংগ্রহের বিধান
# - **বিধিমালা:** জাতীয় রাজস্ব বোর্ড কর্তৃক ধারা ৩৪৩ এর ক্ষমতাবলে প্রণীত **"উৎসে কর বিধিমালা, ২০২৪"** (Withholding Tax Rules, 2024)
#
# ---
#
# ### ২. সর্বশেষ সংশোধনী (SRO)
#
# - **SRO নম্বর:** ২৪৮-আইন/আয়কর-৪২/২০২৪
# - **প্রকাশের তারিখ:** ১৩ আষাঢ়, ১৪৩১ বঙ্গাব্দ (২৭ জুন, ২০২৪ খ্রিষ্টাব্দ)
# - **কার্যকর তারিখ:** ১ জুলাই, ২০২৪
# - **প্রকাশক:** জাতীয় রাজস্ব বোর্ড, অর্থ মন্ত্রণালয়, বাংলাদেশ সরকার
# - **মূল বিষয়বস্তু:**
#   - উৎসে কর বিধিমালার বিধি ৩ এর সারণী প্রতিস্থাপন, যেখানে বিভিন্ন পণ্যের জন্য TDS হার নির্ধারণ করা হয়েছে।
#   - উদাহরণস্বরূপ:
#     - এমএস বিলেট উৎপাদনে নিয়োজিত শিল্প প্রতিষ্ঠানের ক্ষেত্রে ০.৫%
#     - পেট্রোলিয়াম তেল সরবরাহে ০.৬%
#     - অন্যান্য পণ্য ও সেবার জন্য ১% থেকে ৫% পর্যন্ত হার নির্ধারণ।
#   - বিধি ৬ সংশোধনসহ অন্যান্য সংশোধনী অন্তর্ভুক্ত।
#
# ---
#
# ### ৩. বিধিমালার মূল বৈশিষ্ট্য ও হারসমূহ (সারণী থেকে সংক্ষেপে)
#
# | ক্রমিক নং | বর্ণনা | হার |
# |------------|---------|-----|
# | ১ | এমএস বিলেট উৎপাদনে নিয়োজিত শিল্প প্রতিষ্ঠান ও স্থানীয় এমএস স্ক্র্যাপ | ০.৫% |
# | ২ | তেল বিপণন কোম্পানি কর্তৃক তেল সরবরাহ | ০.৬% |
# | ৩ | তেল বিপণন কোম্পানির ফিলিং স্টেশন ব্যতীত অন্য ডিলার বা এজেন্ট | ১% |
# | ৪ | ধান, চাল, গম, আলু, মাছ, মাংস, পিঁয়াজ, রসুন, ডাল, আটা, ভোজ্যতেল, চিনি ইত্যাদি সরবরাহ | ১% |
# | ৫ | সকল প্রকার ফল সরবরাহ | ২% |
# | ৬ | লৌহ বা লৌহ পণ্য, সিরামিক, সিমেন্ট উৎপাদন | ২% |
# | ৭ | তেলশোধন কার্যক্রমে নিযুক্ত কোম্পানি | ২% |
# | ৮ | গ্যাস বিতরণে নিযুক্ত কোম্পানি | ২% |
# | ৯ | গ্যাস ট্রান্সমিশন কোম্পানি | ৩% |
# | ১০ | উচ্চ ভোল্টেজ পাওয়ার কেবল সরবরাহ | ৩% |
# | ১১ | বই সরবরাহ (সরকার ব্যতীত) | ৩% |
# | ১২ | রিসাইকেল্ড সিসা সরবরাহ | ৩% |
# | ১৩ | শিল্পোপাদনে ব্যবহৃত কাঁচামাল সরবরাহ | ৩% |
# | ১৪ | অন্যান্য পণ্য ও ধারা ৮৯ এর অন্যান্য ক্ষেত্রে | ৫% |
#
# ---
#
# ### ৪. অন্যান্য সংশোধনী ও SRO
#
# - ২০২৫ সালের মে মাসে (SRO নং ১৫৭-আইন/আয়কর-১২/২০২৫) উৎসে কর বিধিমালায় কিছু অতিরিক্ত সংশোধনী হয়েছে, তবে মূল বিধিমালা ও হারসমূহ ২০২৪ সালের SRO ২৪৮-আইন/আয়কর-৪২/২০২৪ দ্বারা নির্ধারিত।
# - অন্যান্য SRO যেমন ৪১৭-আইন/আয়কর-৬০/২০২৪ ও ৪০২-আইন/আয়কর-৫৫/২০২৪ আয়কর আইনের ষষ্ঠ তফসিল সংশোধন সম্পর্কিত, যা TDS বিধিমালার সরাসরি সংশোধন নয়।
#
# ---
#
# ### ৫. আইনি পথ ও সূত্র
#
# - **আইন:** আয়কর আইন, ২০২৩ (Income-tax Act, 2023), ধারা ৫২(১)(ক) ও ধারা ৩৪৩
# - **বিধিমালা:** উৎসে কর বিধিমালা, ২০২৪ (TDS Rules, 2024)
# - **সংশোধনী:** এস. আর. ও নং ২৪৮-আইন/আয়কর-৪২/২০২৪ (২৭ জুন, ২০২৪)
# - **সরকারি প্রকাশনা:** বাংলাদেশ গেজেট, অতিরিক্ত সংখ্যা
# - **প্রকাশক:** জাতীয় রাজস্ব বোর্ড (NBR), অর্থ মন্ত্রণালয়, বাংলাদেশ সরকার
# - **ওয়েবসাইট:** [www.bgpress.gov.bd](http://www.bgpress.gov.bd)
#
# ---
#
# ### ৬. সারসংক্ষেপ
#
# - আয়কর আইন, ২০২৩ এর ধারা ৫২(১)(ক) অনুযায়ী TDS এর বিধিমালা হলো **"উৎসে কর বিধিমালা, ২০২৪"**।
# - সর্বশেষ সংশোধনী এস. আর. ও নং **২৪৮-আইন/আয়কর-৪২/২০২৪**, তারিখ ২৭ জুন ২০২৪, যা ১ জুলাই ২০২৪ থেকে কার্যকর।
# - বিধিমালায় বিভিন্ন পণ্য ও সেবার জন্য নির্দিষ্ট TDS হার নির্ধারণ করা হয়েছে।
# - ২০২৫ সালের সংশোধনীগুলো থাকলেও মূল বিধিমালা ও হারসমূহ ২০২৪ সালের SRO দ্বারা নিয়ন্ত্রিত।
# - অন্যান্য SRO গুলো আয়কর আইনের অন্যান্য ধারার সংশোধন সম্পর্কিত, TDS বিধিমালার সাথে সরাসরি সম্পর্কিত নয়।
#
# ---
#
# আপনার যদি আরও বিস্তারিত বা নির্দিষ্ট বিষয়ে প্রশ্ন থাকে, আমি সাধ্যমতো সাহায্য করতে প্রস্তুত আছি।
#
# ধন্যবাদান্তে,
# আপনার আইনি সহকারী
# [www.bgpress.gov.bd](http://www.bgpress.gov.bd)
# [{'index': 'rules', 'id': '60bf82ee-892a-498f-adcb-efafb809d3f7', 'title': 'উৎসে কর বিধিমালা', 'date': None, 'score': 0.616191924, 'url': None}, {'index': 'rules', 'id': '88b564f8-a0e7-481f-b03f-ef469e0ee733', 'title': 'উৎসে কর বিধিমালা', 'date': None, 'score': 0.586717606, 'url': None}, {'index': 'rules', 'id': '3f44f5b9-f493-4eba-9762-b539c2485e2b', 'title': 'উৎসে কর বিধিমালা', 'date': None, 'score': 0.558746338, 'url': None}, {'index': 'rules', 'id': 'c3809a09-6e47-4859-a471-71b09d68a42c', 'title': 'উৎসে কর বিধিমালা', 'date': None, 'score': 0.557062149, 'url': None}, {'index': 'rules', 'id': '95a7e453-e66c-4c3b-8255-3cc3ce67bbde', 'title': None, 'date': None, 'score': 0.556966841, 'url': None}, {'index': 'rules', 'id': '0fc3c585-9a9c-49cf-bc75-ba566d70b76f', 'title': 'TDS Rules', 'date': None, 'score': 0.53247261, 'url': None}, {'index': 'sro', 'id': '957e9ffc-2c5c-44a3-8c94-5a8bf9bab0b2', 'title': None, 'date': None, 'score': 0.440040588, 'url': None}, {'index': 'sro', 'id': '80c736d8-55e7-4f0a-85e6-4fa30c3a73d9', 'title': None, 'date': None, 'score': 0.436565399, 'url': None}, {'index': 'sro', 'id': '88b6a2e9-1d69-4a96-ae7f-d761d08771a1', 'title': None, 'date': None, 'score': 0.432136536, 'url': None}, {'index': 'sro', 'id': '462d636c-3612-4a05-a5bc-253e346eeb76', 'title': None, 'date': None, 'score': 0.431230545, 'url': None}, {'index': 'ordinances', 'id': '02a8f150-fcf9-4411-a1c3-2def966b347b', 'title': None, 'date': None, 'score': 0.405643463, 'url': None}, {'index': 'ordinances', 'id': 'fb4095ab-f65e-40da-9a95-7e679e32d9bd', 'title': None, 'date': None, 'score': 0.40180397, 'url': None}]

# %%
out = run_legal_query(
    "Is there any option to get refund of my excess paid tax? Explain in details",
    use_web=True
)
print(out.final_answer)
print(out.citations)
# Out:
# আপনার অতিরিক্ত পরিশোধিত কর ফেরতের বিষয়ে বিস্তারিত ব্যাখ্যা নিচে প্রদান করা হলো:
#
# ---
#
# ### ১. কর ফেরতের আইনি সুযোগ ও বিধানসমূহ
#
# - **আয়কর আইন, ২০২৩ এর ধারা ২২৪** অনুযায়ী, যদি কোনো ব্যক্তি উপকর কমিশনারকে সন্তুষ্ট করতে পারেন যে, কোনো করবছরে তিনি বা তার পক্ষে পরিশোধিত করের পরিমাণ তার করদায়িত্বের চেয়ে বেশি হয়েছে, তবে তিনি অতিরিক্ত পরিশোধিত কর ফেরত পাওয়ার অধিকারী হবেন।
# - এই ধারা স্পষ্টভাবে করদাতাদের অতিরিক্ত কর ফেরত পাওয়ার অধিকার নিশ্চিত করে।
# - **ধারা ২২৫** অনুসারে, কর ফেরতের দাবির ক্ষেত্রে যদি করদাতার উপর কোনো বকেয়া অর্থ থাকে, তবে সেই বকেয়া অর্থ ফেরতের আগে সমন্বয় করা হবে। অর্থাৎ, বকেয়া থাকলে সেটি ফেরতের টাকা থেকে কর্তন করা হবে।
#
# ---
#
# ### ২. উৎসে কর (TDS) সম্পর্কিত বিধান ও সনদপত্র
#
# - **উৎসে কর বিধিমালা, ২০২৪** (TDS Rules, 2024) অনুযায়ী, উৎসে কর কর্তন ও জমাদানের নিয়মাবলী নির্ধারিত হয়েছে।
# - **বিধি ১১(১)** অনুযায়ী চাকরি থেকে আয় হতে উৎসে কর কর্তনের সনদপত্র প্রদান করা হয়, যা কর পরিশোধের প্রমাণ হিসেবে ব্যবহৃত হয়।
# - কর কর্তনকারী কর্তৃপক্ষ কর্তৃক প্রদত্ত এই সনদপত্র করদাতাকে কর পরিশোধের তথ্য নিশ্চিত করতে সাহায্য করে।
# - তবে, এই বিধিমালায় সরাসরি কর ফেরতের প্রক্রিয়া বর্ণিত না থাকলেও, কর কর্তনের পরিমাণ বেশি হলে করদাতা আইন অনুযায়ী ফেরত দাবি করতে পারেন।
#
# ---
#
# ### ৩. কর ফেরতের প্রক্রিয়া
#
# - অতিরিক্ত কর ফেরতের জন্য করদাতাকে সংশ্লিষ্ট **উপকর কমিশনার** বা **ডেপুটি কমিশনার (Deputy Commissioner of Taxes)** এর কাছে আবেদন করতে হবে।
# - আবেদন করার সময় কর পরিশোধের প্রমাণাদি (যেমন: TDS সার্টিফিকেট, ব্যাংক স্টেটমেন্ট, চালান ইত্যাদি) জমা দিতে হবে।
# - কর কর্তন ও জমাদানের সনদপত্র (যেমন তফসিল ২ অনুযায়ী) এবং অন্যান্য প্রাসঙ্গিক দলিলাদি সংযুক্ত করতে হবে।
# - কর কর্তৃপক্ষ আবেদন যাচাই-বাছাই করে অতিরিক্ত পরিশোধিত কর ফেরত প্রদান করবেন, তবে বকেয়া কর থাকলে সেটি ফেরতের টাকা থেকে কর্তন করা হবে।
# - এই প্রক্রিয়া আইনের ধারা ২২৪ ও ২২৫ এর আওতায় সম্পন্ন হয়।
#
# ---
#
# ### ৪. সাম্প্রতিক সংশোধনী ও অবস্থা
#
# - সর্বশেষ **এস.আর.ও নং ২৪৮-আইন/আয়কর-৪২/২০২৪** (তারিখ: ২৭ জুন ২০২৪) দ্বারা উৎসে কর বিধিমালা, ২০২৪ সংশোধিত হয়েছে, যা উৎসে কর হার ও বিধান সংশোধন করেছে, কিন্তু কর ফেরতের অধিকার বা প্রক্রিয়ায় কোনো পরিবর্তন আনে নি।
# - **এস.আর.ও নং ৩৪০-আইন/আয়কর-৪৮/২০২৪** (তারিখ: ৯ অক্টোবর ২০২৪) দ্বারা আয়কর আইনের ষষ্ঠ সূচি সংশোধিত হয়েছে, যা কর হার ও অন্যান্য বিষয় সংশোধন করেছে, তবে কর ফেরতের বিধান অপরিবর্তিত রয়েছে।
# - অর্থাৎ, বর্তমান আইন ও বিধিমালা অনুযায়ী অতিরিক্ত কর ফেরত পাওয়ার অধিকার সম্পূর্ণ বৈধ ও কার্যকর।
#
# ---
#
# ### ৫. সংক্ষিপ্ত সারাংশ
#
# - আপনার অতিরিক্ত পরিশোধিত কর ফেরত পাওয়ার জন্য **আয়কর আইন, ২০২৩ এর ধারা ২২৪** অনুসারে আবেদন করতে হবে।
# - আবেদন প্রক্রিয়ায় কর পরিশোধের প্রমাণাদি ও সংশ্লিষ্ট সনদপত্র (যেমন TDS সার্টিফিকেট) জমা দিতে হবে।
# - কর কর্তৃপক্ষ যাচাই-বাছাই শেষে অতিরিক্ত কর ফেরত প্রদান করবে, তবে বকেয়া থাকলে সেটি কর্তন করা হবে।
# - উৎসে কর বিধিমালা, ২০২৪ এবং সাম্প্রতিক সংশোধনী কর ফেরতের অধিকারকে প্রভাবিত করে না।
#
# ---
#
# ### ৬. আইনি উৎস ও রেফারেন্স
#
# | আইন/বিধি/এস.আর.ও | বিষয় | লিঙ্ক (বাংলাদেশ সরকারী প্রকাশনা) |
# |------------------|---------|----------------------------------|
# | আয়কর আইন, ২০২৩ (Income Tax Act, 2023) ধারা ২২৪-২২৫ | কর ফেরতের অধিকার ও সমন্বয় | [www.bgpress.gov.bd](https://www.bgpress.gov.bd) |
# | উৎসে কর বিধিমালা, ২০২৪ (TDS Rules, 2024) বিধি ১১ | কর কর্তনের সনদপত্র | [www.bgpress.gov.bd](https://www.bgpress.gov.bd) |
# | এস.আর.ও নং ২৪৮-আইন/আয়কর-৪২/২০২৪ | উৎসে কর বিধিমালা সংশোধনী | [www.bgpress.gov.bd](https://www.bgpress.gov.bd) |
# | এস.আর.ও নং ৩৪০-আইন/আয়কর-৪৮/২০২৪ | আয়কর আইন ষষ্ঠ সূচি সংশোধনী | [www.bgpress.gov.bd](https://www.bgpress.gov.bd) |
#
# ---
#
# ### উপসংহার
#
# আপনি যদি কোনো করবছরে অতিরিক্ত কর পরিশোধ করে থাকেন, তাহলে আয়কর আইন, ২০২৩ এর ধারা ২২৪ অনুযায়ী কর কর্তৃপক্ষের কাছে আবেদন করে সেই অতিরিক্ত কর ফেরত পেতে পারেন। আবেদন প্রক্রিয়ায় প্রয়োজনীয় দলিলাদি জমা দিতে হবে এবং বকেয়া কর থাকলে সেটি সমন্বয় করা হবে। উৎসে কর বিধিমালা ও সাম্প্রতিক সংশোধনী কর ফেরতের অধিকারকে প্রভাবিত করে না। তাই আপনার অধিক পরিশোধিত কর ফেরত পাওয়ার আইনি সুযোগ রয়েছে।
#
# ---
#
# যদি আরও বিস্তারিত বা প্রক্রিয়া সংক্রান্ত সাহায্য প্রয়োজন হয়, আমি সাহায্য করতে প্রস্তুত আছি। ধন্যবাদ।
#
# ---
#
# **আপনার কর ফেরত সংক্রান্ত যেকোনো প্রশ্নের জন্য জাতীয় রাজস্ব বোর্ডের অফিসিয়াল ওয়েবসাইটে ভিজিট করতে পারেন:**
# [https://nbr.gov.bd](https://nbr.gov.bd)
#
# ---
#
# আশা করি উপরের তথ্য আপনার প্রশ্নের যথাযথ ও বিস্তারিত উত্তর প্রদান করেছে।
# সৌজন্যে, আপনার আইনি সহকারী।
# [{'index': 'rules', 'id': '31afd174-bd43-461b-8f1c-4d140ffa35e1', 'title': 'TDS Rules, 2024', 'date': None, 'score': 0.342933655, 'url': None}, {'index': 'rules', 'id': '60bf82ee-892a-498f-adcb-efafb809d3f7', 'title': 'উৎসে কর বিধিমালা', 'date': None, 'score': 0.327178985, 'url': None}, {'index': 'rules', 'id': '95a7e453-e66c-4c3b-8255-3cc3ce67bbde', 'title': None, 'date': None, 'score': 0.293571502, 'url': None}, {'index': 'rules', 'id': 'c3809a09-6e47-4859-a471-71b09d68a42c', 'title': 'উৎসে কর বিধিমালা', 'date': None, 'score': 0.292036057, 'url': None}, {'index': 'rules', 'id': '3f44f5b9-f493-4eba-9762-b539c2485e2b', 'title': 'উৎসে কর বিধিমালা', 'date': None, 'score': 0.29193306, 'url': None}, {'index': 'rules', 'id': '1bea8913-8a84-40ea-962a-557000a8b52e', 'title': 'TDS Rules, 2024', 'date': None, 'score': 0.291517228, 'url': None}, {'index': 'acts', 'id': 'deb627f0-c1cd-47b6-bacf-bcaba2cb6ac5', 'title': 'আয়কর আইন', 'date': None, 'score': 0.268104553, 'url': None}, {'index': 'acts', 'id': '36cc286d-c68b-416b-b947-c07d32f8a8dd', 'title': 'আয়কর আইন', 'date': None, 'score': 0.268104553, 'url': None}, {'index': 'acts', 'id': '461a13d0-f133-421b-b5fe-13f06aff5576', 'title': 'আয়কর আইন', 'date': None, 'score': 0.26725769, 'url': None}, {'index': 'acts', 'id': '8c1e576e-8006-4a69-b9c4-d247e6694856', 'title': 'Income Tax Act (inferred)', 'date': None, 'score': 0.261707306, 'url': None}, {'index': 'ordinances', 'id': 'cd96e79b-6de8-47ea-9b8d-4e63628e7683', 'title': None, 'date': None, 'score': 0.261455536, 'url': None}, {'index': 'ordinances', 'id': '789e1389-9e13-47e0-97d7-8f9e31e22e3b', 'title': None, 'date': None, 'score': 0.260173827, 'url': None}]

# %%
out = run_legal_query(
    "How can I reduce my income tax?",
    use_web=True
)
print(out.final_answer)
print(out.citations)
# Out:
# আপনার আয়কর কমানোর জন্য বাংলাদেশের বর্তমান আইন ও সংশোধিত বিধিমালা অনুসারে প্রধানত নিম্নলিখিত উপায়সমূহ গ্রহণ করতে পারেন:
#
# ---
#
# ### আয়কর কমানোর উপায়সমূহ (বাংলায়):
#
# - **১. অনুমোদিত দানে কর বিয়োজন (Deduction for Approved Donations):**
#   আয়কর আইন, ২০২৩ এর ষষ্ঠ তফসিল (ধারা ৭৬ দ্রষ্টব্য) অনুযায়ী, আপনি যদি ব্যাংক ট্রান্সফারের মাধ্যমে প্রধানমন্ত্রীর শিক্ষা সহায়তা ট্রাস্ট, সরকারি অনুমোদিত বালিকা বিদ্যালয়, মহিলা কলেজ, কারিগরি প্রশিক্ষণ প্রতিষ্ঠান অথবা কৃষি, বিজ্ঞান, প্রযুক্তি ও শিল্প উন্নয়নের জন্য গবেষণা ও উন্নয়নের সাথে সম্পৃক্ত জাতীয় পর্যায়ের প্রতিষ্ঠানে দান করেন, তবে সেই দানের পরিমাণ আপনার মোট আয় থেকে বিয়োজনযোগ্য হবে।
#   - কোম্পানির ক্ষেত্রে সর্বোচ্চ ১০% বা ৮ কোটি টাকা (যা কম) পর্যন্ত দান কর বিয়োজনযোগ্য।
#   - অন্যান্য করদাতাদের ক্ষেত্রে সর্বোচ্চ ১০% বা ১ কোটি টাকা (যা কম) পর্যন্ত।
#   - ২০২৪ সালের SRO 340 (৯ অক্টোবর ২০২৪) অনুযায়ী, As-Sunnah Foundation-এ দানও এই সুবিধার আওতায় এসেছে।
#   - **আইনি উৎস:** আয়কর আইন, ২০২৩, অংশ ২, ধারা ৭৬; SRO 340-আইন/আয়কর-৪৮/২০২৪
#   - **সূত্র:** [www.bgpress.gov.bd](http://www.bgpress.gov.bd)
#
# - **২. প্রতিবন্ধী ও তৃতীয় লিঙ্গ কর্মচারী নিয়োগে কর রিবেট:**
#   ২০২৫ সালের ফাইন্যান্স অধ্যাদেশ অনুযায়ী, যদি কোনো প্রতিষ্ঠান তাদের মোট কর্মচারীর অন্তত ১০% বা ২৫% প্রতিবন্ধী বা তৃতীয় লিঙ্গের কর্মচারী নিয়োগ করে, তবে তারা আয়কর থেকে যথাক্রমে ৫% পর্যন্ত বা মোট বেতন খরচের ৭৫% পর্যন্ত কর রিবেট পেতে পারে। এটি করযোগ্য আয় কমাতে সহায়ক।
#   - **আইনি উৎস:** Finance Ordinance, 2025 (অধ্যাদেশ নং ২৮, ২০২৫)
#   - **সূত্র:** সরকারি গেজেট প্রকাশনা
#
# - **৩. উৎসে কর (TDS) পরিকল্পনা:**
#   জাতীয় রাজস্ব বোর্ডের ২০২৪ সালের সংশোধিত উৎসে কর বিধিমালা অনুযায়ী বিভিন্ন পণ্যের সরবরাহ ও সেবার ক্ষেত্রে উৎসে করের হার নির্ধারিত হয়েছে (০.৫% থেকে ৫% পর্যন্ত)।
#   - উৎসে কর মূলত কর আদায়ের একটি মাধ্যম, তবে সঠিক পরিকল্পনার মাধ্যমে নগদ প্রবাহ নিয়ন্ত্রণ ও করের সময়মতো পরিশোধ নিশ্চিত করে করদায়িত্ব কমানো সম্ভব।
#   - **আইনি উৎস:** উৎসে কর বিধিমালা, ২০২৪ (সংশোধন ২৭ জুন ২০২৪, SRO ২৪৮)
#   - **সূত্র:** [www.bgpress.gov.bd](http://www.bgpress.gov.bd)
#
# - **৪. কর প্রত্যর্পণ ও সমন্বয়:**
#   অতিরিক্ত কর পরিশোধ হলে উপকর কমিশনারের মাধ্যমে কর প্রত্যর্পণ দাবি করা যায়। এছাড়া, বকেয়া কর থাকলে সেটি সমন্বয় করে কর রেকর্ড সঠিক রাখা জরুরি।
#   - **আইনি উৎস:** আয়কর আইন, ২০২৩, ধারা ২২৪-২২৫
#   - **সূত্র:** আয়কর আইন, ২০২৩
#
# ---
#
# ### সামগ্রিক আইনি পথ ও সর্বশেষ অবস্থা:
#
# - **আয়কর আইন, ২০২৩** (২০২৩ সালের ২২ জুন কার্যকর) হলো বর্তমান কর আইন যা পুরনো আয়কর অধ্যাদেশের স্থলাভিষিক্ত।
# - **SRO 340 (৯ অক্টোবর ২০২৪)** দ্বারা দানের ক্ষেত্রে কর বিয়োজনের সুযোগ সম্প্রসারিত হয়েছে, বিশেষ করে As-Sunnah Foundation অন্তর্ভুক্ত হয়েছে।
# - **উৎসে কর বিধিমালা, ২০২৪** (সংশোধিত ২৭ জুন ২০২৪) অনুযায়ী কর কর্তনের হার নির্ধারণ করা হয়েছে যা কর আদায়ে প্রভাব ফেলে।
# - **Finance Ordinance, 2025** (অধ্যাদেশ নং ২৮, ২০২৫) প্রতিবন্ধী ও তৃতীয় লিঙ্গ কর্মচারী নিয়োগে কর রিবেট প্রদান করে।
# - কর প্রত্যর্পণ ও সমন্বয় বিধান করদাতাদের অতিরিক্ত কর ফেরত পাওয়ার সুযোগ দেয়।
#
# ---
#
# ### উপসংহার:
#
# আপনার আয়কর কমানোর জন্য প্রধানত:
#
# - অনুমোদিত শিক্ষা ও গবেষণা প্রতিষ্ঠানে ব্যাংক ট্রান্সফারের মাধ্যমে দান করুন (আয়কর থেকে বিয়োজন পাবেন)।
# - প্রতিবন্ধী ও তৃতীয় লিঙ্গ কর্মচারী নিয়োগের মাধ্যমে কর রিবেট নিন।
# - উৎসে কর বিধিমালা অনুযায়ী কর কর্তনের সঠিক পরিকল্পনা করুন।
# - অতিরিক্ত কর পরিশোধ হলে প্রত্যর্পণের জন্য আবেদন করুন।
#
# এই সকল ব্যবস্থা গ্রহণ করলে আপনার করযোগ্য আয় ও করের পরিমাণ যথেষ্ট কমানো সম্ভব হবে।
#
# ---
#
# ### উল্লেখযোগ্য আইনি উৎস ও লিঙ্ক:
#
# - **আয়কর আইন, ২০২৩**: [www.bgpress.gov.bd](http://www.bgpress.gov.bd)
# - **SRO 340-আইন/আয়কর-৪৮/২০২৪ (৯ অক্টোবর ২০২৪)**
# - **উৎসে কর বিধিমালা, ২০২৪ (সংশোধন ২৭ জুন ২০২৪)**
# - **Finance Ordinance, 2025 (অধ্যাদেশ নং ২৮, ২০২৫)**
#
# ---
#
# আপনার কর পরিকল্পনা আরও বিস্তারিত ও ব্যক্তিগতকৃত করতে একজন যোগ্য কর পরামর্শকের সাথে পরামর্শ করার পরামর্শ রইল। আশা করি এই তথ্য আপনার জন্য সহায়ক হবে। ধন্যবাদ।
# [{'index': 'rules', 'id': '31afd174-bd43-461b-8f1c-4d140ffa35e1', 'title': 'TDS Rules, 2024', 'date': None, 'score': 0.313482285, 'url': None}, {'index': 'rules', 'id': '60bf82ee-892a-498f-adcb-efafb809d3f7', 'title': 'উৎসে কর বিধিমালা', 'date': None, 'score': 0.281003982, 'url': None}, {'index': 'acts', 'id': '5b27a3b1-9bf8-4d9d-b802-74606e8a9b31', 'title': 'আয়কর আইন', 'date': None, 'score': 0.25737381, 'url': None}, {'index': 'acts', 'id': '8c1e576e-8006-4a69-b9c4-d247e6694856', 'title': 'Income Tax Act (inferred)', 'date': None, 'score': 0.24977684, 'url': None}, {'index': 'ordinances', 'id': 'cd96e79b-6de8-47ea-9b8d-4e63628e7683', 'title': None, 'date': None, 'score': 0.248104095, 'url': None}, {'index': 'acts', 'id': '461a13d0-f133-421b-b5fe-13f06aff5576', 'title': 'আয়কর আইন', 'date': None, 'score': 0.238824844, 'url': None}, {'index': 'acts', 'id': '676ce115-ae93-4490-9b5a-88c0d6efafa8', 'title': 'Income-tax Act, 2023', 'date': None, 'score': 0.235797882, 'url': None}, {'index': 'acts', 'id': 'deb627f0-c1cd-47b6-bacf-bcaba2cb6ac5', 'title': 'আয়কর আইন', 'date': None, 'score': 0.235218048, 'url': None}, {'index': 'acts', 'id': '36cc286d-c68b-416b-b947-c07d32f8a8dd', 'title': 'আয়কর আইন', 'date': None, 'score': 0.235218048, 'url': None}, {'index': 'rules', 'id': '88b564f8-a0e7-481f-b03f-ef469e0ee733', 'title': 'উৎসে কর বিধিমালা', 'date': None, 'score': 0.234668732, 'url': None}, {'index': 'rules', 'id': '95a7e453-e66c-4c3b-8255-3cc3ce67bbde', 'title': None, 'date': None, 'score': 0.233003631, 'url': None}, {'index': 'rules', 'id': '3f44f5b9-f493-4eba-9762-b539c2485e2b', 'title': 'উৎসে কর বিধিমালা', 'date': None, 'score': 0.23238945, 'url': None}]

# %%
out = run_legal_query(
    "Please provide the list of exempted income for individuals. Tell me in details",
    use_web=True
)
print(out.final_answer)
print(out.citations)
# Out:
# বাংলাদেশের আয়কর আইন, ২০২৩ (Income Tax Act, 2023) এবং সর্বশেষ সংশোধনসমূহ (বিশেষ করে এসআরও ৩৪০/২০২৪, ৯ অক্টোবর ২০২৪ তারিখে জারি) অনুযায়ী, ব্যক্তিদের জন্য যে আয়সমূহ করমুক্ত বা exempted income হিসেবে গণ্য হয়, তা নিম্নরূপ বিস্তারিতভাবে উপস্থাপন করা হলো:
#
# ---
#
# ### ব্যক্তিদের জন্য করমুক্ত আয়ের তালিকা (Exempted Income for Individuals):
#
# ১. **আন্তর্জাতিক ও আন্তঃসরকারি সংস্থার আয়**
#    - যেকোনো আন্তর্জাতিক বা আন্তঃসরকারি সংস্থা এবং তাদের কর্মচারীদের আয়, যা আইন বা সরকারী চুক্তি অনুযায়ী করমুক্ত।
#    - যেমন: জাতিসংঘ, বিশ্বব্যাংক ইত্যাদি সংস্থার কর্মচারীদের বেতন ও অন্যান্য আয়।
#    - **আইনগত উৎস:** Income Tax Act, 2023, Section 76 এবং Sixth Schedule।
#
# ২. **বিদেশী কূটনীতিক ও সরকারী প্রতিনিধি বেতন-ভাতা**
#    - বিদেশী রাষ্ট্রের কূটনীতিক, দূতাবাসের কর্মকর্তা ও নির্দিষ্ট সরকারী প্রতিনিধি যারা বাংলাদেশ সরকারের অনুমোদিত, তাদের বেতন ও ভাতা করমুক্ত।
#    - **আইনগত উৎস:** Income Tax Act, 2023, সংশ্লিষ্ট ধারা ও Sixth Schedule।
#
# ৩. **অনুমোদিত দাতব্য ও শিক্ষা প্রতিষ্ঠানসমূহে দান**
#    - করদাতারা ব্যাংক ট্রান্সফারের মাধ্যমে নিম্নলিখিত অনুমোদিত প্রতিষ্ঠানসমূহে দান করলে সেই দান করমুক্ত:
#      - প্রধানমন্ত্রী শিক্ষা সহায়তা তহবিল (Prime Minister's Education Assistance Trust) নির্দিষ্ট সীমার মধ্যে।
#      - সরকার অনুমোদিত বালিকা বিদ্যালয় ও মহিলা কলেজ।
#      - সরকার অনুমোদিত কারিগরি ও বৃত্তিমূলক প্রশিক্ষণ প্রতিষ্ঠান।
#      - কৃষি, বিজ্ঞান, প্রযুক্তি, শিল্প গবেষণা ও উন্নয়ন সংক্রান্ত জাতীয় পর্যায়ের প্রতিষ্ঠান।
#      - **নতুন সংযোজন:** As-Sunnah Foundation-এ দান (এসআরও ৩৪০/২০২৪ এর মাধ্যমে ৯ অক্টোবর ২০২৪ থেকে কার্যকর)।
#    - **আইনগত উৎস:** Income Tax Act, 2023, Sixth Schedule; SRO 340/2024।
#
# ৪. **অন্যান্য করমুক্ত আয়**
#    - বর্তমানে প্রাপ্ত তথ্য অনুযায়ী, অন্যান্য করমুক্ত আয়ের বিস্তারিত তালিকা (যেমন কৃষি আয়, নির্দিষ্ট পেনশন ইত্যাদি) সরাসরি পাওয়া যায়নি।
#    - বিস্তারিত ও পূর্ণাঙ্গ করমুক্ত আয়ের জন্য Income Tax Act, 2023 এর Sixth Schedule এবং সংশ্লিষ্ট ধারা পর্যালোচনা করা প্রয়োজন।
#
# ---
#
# ### উল্লেখযোগ্য আইন ও বিধিমালা:
#
# - **Income Tax Act, 2023** (Effective from 22 June 2023)
#   - প্রধান আইন যা করমুক্ত আয়ের বিধান দেয়।
#   - [আইনের পূর্ণপাঠ (বাংলা)](https://www.bgpress.gov.bd) (সরকারি প্রকাশনা)
#
# - **SRO 340/2024 (9 October 2024)**
#   - সর্বশেষ সংশোধনী যা As-Sunnah Foundation-এ দান করমুক্ত ঘোষণা করেছে।
#   - [জাতীয় রাজস্ব বোর্ডের প্রজ্ঞাপন (SRO)](https://www.bgpress.gov.bd)
#
# - **উৎসে কর বিধিমালা, ২০২৪**
#   - কর কর্তনের হার ও বিধি নির্ধারণ করে, তবে করমুক্ত আয়ের তালিকা সরাসরি দেয় না।
#
# ---
#
# ### সংক্ষিপ্ত সারাংশ (Summary in English):
#
# - Under the Income Tax Act, 2023 and latest amendments (notably SRO 340 dated 9 October 2024), exempted incomes for individuals primarily include:
#   - Income of international/intergovernmental organizations and their employees exempted by law or government agreement.
#   - Salaries and allowances of foreign diplomats and government representatives approved by the government.
#   - Donations made via bank transfer to approved trusts and institutions such as the Prime Minister's Education Assistance Trust, government-approved girls' schools, technical institutes, national research institutions, and newly added As-Sunnah Foundation.
# - The Act and amendments do not provide an exhaustive list of all exempted incomes in the retrieved texts; for comprehensive details, refer to the Sixth Schedule of the Income Tax Act, 2023.
#
# ---
#
# ### উপসংহার:
#
# বর্তমানে বাংলাদেশে ব্যক্তিদের করমুক্ত আয়ের প্রধান উৎসসমূহ হলো আন্তর্জাতিক সংস্থা ও কূটনৈতিক বেতন, অনুমোদিত দাতব্য ও শিক্ষা প্রতিষ্ঠানসমূহে দান। সর্বশেষ এসআরও ৩৪০/২০২৪ অনুযায়ী As-Sunnah Foundation-এ দান করমুক্ত হয়েছে। বিস্তারিত ও অন্যান্য করমুক্ত আয়ের জন্য আয়কর আইনের সংশ্লিষ্ট ধারা ও তফসিল পর্যালোচনা করা আবশ্যক।
#
# ---
#
# যদি আরও বিস্তারিত বা নির্দিষ্ট আয়ের করমুক্তির তথ্য প্রয়োজন হয়, তাহলে Income Tax Act, 2023 এর Sixth Schedule এবং সংশ্লিষ্ট SRO গুলো (বিশেষ করে SRO 340/2024) পর্যালোচনা করার পরামর্শ দেওয়া হয়।
#
# ---
#
# **সূত্র:**
# - Income Tax Act, 2023 (22 June 2023)
# - SRO 340/2024 (9 October 2024) — [www.bgpress.gov.bd](https://www.bgpress.gov.bd)
# - National Board of Revenue (NBR) official notifications and rules
#
# ---
#
# আপনার যদি আরও নির্দিষ্ট কোনো আয়ের করমুক্তির বিষয়ে প্রশ্ন থাকে, জানালে বিস্তারিত সহ সাহায্য করব।
# [{'index': 'acts', 'id': 'deb627f0-c1cd-47b6-bacf-bcaba2cb6ac5', 'title': 'আয়কর আইন', 'date': None, 'score': 0.350187331, 'url': None}, {'index': 'acts', 'id': '36cc286d-c68b-416b-b947-c07d32f8a8dd', 'title': 'আয়কর আইন', 'date': None, 'score': 0.350187331, 'url': None}, {'index': 'acts', 'id': '461a13d0-f133-421b-b5fe-13f06aff5576', 'title': 'আয়কর আইন', 'date': None, 'score': 0.347499877, 'url': None}, {'index': 'rules', 'id': '60bf82ee-892a-498f-adcb-efafb809d3f7', 'title': 'উৎসে কর বিধিমালা', 'date': None, 'score': 0.344207793, 'url': None}, {'index': 'rules', 'id': '31afd174-bd43-461b-8f1c-4d140ffa35e1', 'title': 'TDS Rules, 2024', 'date': None, 'score': 0.334938079, 'url': None}, {'index': 'rules', 'id': '7d50359f-4305-4973-a823-65949b300e1c', 'title': 'TDS Rules, 2024', 'date': None, 'score': 0.321807891, 'url': None}, {'index': 'rules', 'id': '95a7e453-e66c-4c3b-8255-3cc3ce67bbde', 'title': None, 'date': None, 'score': 0.318819076, 'url': None}, {'index': 'rules', 'id': 'c3809a09-6e47-4859-a471-71b09d68a42c', 'title': 'উৎসে কর বিধিমালা', 'date': None, 'score': 0.318252593, 'url': None}, {'index': 'rules', 'id': '3f44f5b9-f493-4eba-9762-b539c2485e2b', 'title': 'উৎসে কর বিধিমালা', 'date': None, 'score': 0.318185836, 'url': None}, {'index': 'acts', 'id': '676ce115-ae93-4490-9b5a-88c0d6efafa8', 'title': 'Income-tax Act, 2023', 'date': None, 'score': 0.314624816, 'url': None}, {'index': 'acts', 'id': '314938e0-98ed-48da-a7da-2af185c38b87', 'title': 'Income-tax Act, 2023', 'date': None, 'score': 0.31435588, 'url': None}, {'index': 'acts', 'id': 'cc095f68-2d23-436e-acb8-813433d9f870', 'title': 'Income-tax Act, 2023', 'date': None, 'score': 0.313520461, 'url': None}]

# %%
out = run_legal_query(
    "ক্লায়েন্ট আমার কাছে রির্টান দাখিলের প্রমান চাচ্ছে এখন আমি কি করবো?",
    use_web=True
)
print(out.final_answer)
print(out.citations)
# Out:
# আপনার ক্লায়েন্ট রিটার্ন দাখিলের প্রমাণ চাচ্ছে, এ ক্ষেত্রে আপনি কী করবেন—এ বিষয়ে বিস্তারিত ব্যাখ্যা ও আইনি নির্দেশনা নিচে দেওয়া হলো।
#
# ---
#
# ### সমস্যা ও প্রাসঙ্গিক সংজ্ঞা
#
# **রিটার্ন দাখিলের প্রমাণ** বলতে বোঝায় করদাতা কর্তৃক আয়কর রিটার্ন জমা দেওয়ার যে নথিপত্র বা প্রমাণাদি, যা করদাতার ব্যবসা বা আয়ের স্থানে সহজে প্রদর্শনযোগ্য হয়। এটি করদাতার রিটার্ন দাখিলের বাধ্যবাধকতা পূরণের প্রমাণ হিসেবে ব্যবহৃত হয়।
#
# বাংলাদেশের **আয়কর আইন, ২০২৩** এর ধারা ২৬৫ অনুযায়ী:
#
# - করদাতাদের রিটার্ন দাখিলের প্রমাণ তাদের ব্যবসার স্থানে সহজে দৃষ্টিগোচর হয় এমন স্থানে প্রদর্শন করতে হয়।
# - যদি করদাতা এই বিধান পালন না করেন, তাহলে উপকর কমিশনার ৫,০০০ থেকে ২০,০০০ টাকা পর্যন্ত জরিমানা আরোপ করতে পারেন।
# (সূত্র: আয়কর আইন, ২০২৩, ধারা ২৬৫, [source](#))
#
# ---
#
# ### করদাতার কর রিটার্ন দাখিলের প্রমাণ প্রদানের উপায়
#
# ১. **ব্যবসার স্থানে রিটার্নের কপি প্রদর্শন:**
#
#    - করদাতা তার ব্যবসার স্থানে আয়কর রিটার্নের কপি বা সংশ্লিষ্ট নথি সহজে প্রদর্শন করবেন, যাতে কর কর্তৃপক্ষ বা ক্লায়েন্ট প্রমাণ হিসেবে দেখতে পারেন।
#    - এটি আইনানুগ বাধ্যবাধকতা এবং করদাতার দায়িত্ব।
#
# ২. **উৎস কর কর্তন রিটার্ন দাখিলের প্রাপ্তি স্বীকারপত্র (TDS Receipt):**
#
#    - **TDS Rules, ২০২৪** এর বিধি ১৫ অনুযায়ী, উৎস কর কর্তন রিটার্ন দাখিলের পর একটি প্রাপ্তি স্বীকারপত্র ইস্যু করা হয়, যা রিটার্ন দাখিলের অফিসিয়াল প্রমাণ হিসেবে ব্যবহারযোগ্য।
#    - এই স্বীকারপত্রে থাকে করদাতার নাম, টিআইএন, কর অফিসের সীলমোহর, জমা প্রদানের তারিখ ইত্যাদি তথ্য।
#    - ক্লায়েন্টকে এই স্বীকারপত্রের কপি প্রদান করাও একটি গ্রহণযোগ্য প্রমাণ।
#
# ৩. **রিটার্নে স্বাক্ষর ও জমা দেওয়ার তথ্য:**
#
#    - রিটার্নের সাথে থাকা স্বাক্ষর, জমা দেওয়ার তারিখ ও অন্যান্য বিবরণীও প্রমাণ হিসেবে উপস্থাপন করা যেতে পারে।
#    - যেমন: রিটার্ন ফর্মের অংশ ৪ এর ঘোষণাপত্র যেখানে করদাতা স্বাক্ষর করেন এবং তারিখ উল্লেখ থাকে।
#    (সূত্র: TDS Rules, ২০২৪, বিধি ১৫, [source](#))
#
# ---
#
# ### আইনি বিধান ও জরিমানা সম্পর্কিত সতর্কতা
#
# - যদি করদাতা রিটার্ন দাখিলের প্রমাণ প্রদর্শনে ব্যর্থ হন, তাহলে **আয়কর আইন, ২০২৩** এর ধারা ২৬৫(২) অনুযায়ী উপকর কমিশনার ৫,০০০ থেকে ২০,০০০ টাকা পর্যন্ত জরিমানা আরোপ করতে পারেন।
# - অতএব, প্রমাণ প্রদর্শনে যথাযথতা বজায় রাখা করদাতার জন্য জরুরি।
#
# ---
#
# ### আপনার করণীয় (Action Plan)
#
# - ক্লায়েন্টকে তাদের ব্যবসার স্থানে রিটার্ন দাখিলের কপি বা সংশ্লিষ্ট নথি সহজে প্রদর্শন করার জন্য পরামর্শ দিন।
# - যদি ক্লায়েন্টের কাছে থাকে, তাহলে উৎস কর কর্তন রিটার্ন দাখিলের প্রাপ্তি স্বীকারপত্রের কপি সরবরাহ করুন।
# - রিটার্নের স্বাক্ষর ও জমা দেওয়ার তারিখসহ অন্যান্য তথ্যাদি ক্লায়েন্টকে প্রদান করুন, যা প্রমাণ হিসেবে গ্রহণযোগ্য।
# - প্রয়োজনে কর অফিস থেকে রিটার্ন গ্রহণের স্বীকৃতিপত্র (Receipt) সংগ্রহ করে ক্লায়েন্টকে দিন।
# - নিশ্চিত করুন যে, করদাতা আইনানুগ বাধ্যবাধকতা পূরণ করছেন যাতে জরিমানা এড়ানো যায়।
#
# ---
#
# ### সারসংক্ষেপ
#
# - **আইনগত বাধ্যবাধকতা:** আয়কর আইন, ২০২৩, ধারা ২৬৫
# - **জরিমানা:** ৫,০০০ থেকে ২০,০০০ টাকা (ধারা ২৬৫(২))
# - **প্রমাণের ধরন:** ব্যবসার স্থানে রিটার্ন কপি প্রদর্শন, TDS রিটার্ন দাখিলের প্রাপ্তি স্বীকারপত্র, রিটার্নে স্বাক্ষর ও জমা দেওয়ার তথ্য
# - **নিয়মাবলী:** TDS Rules, ২০২৪, বিধি ১৫
# - **অতিরিক্ত:** রিটার্ন দাখিলের সময়সীমা ও নোটিশ সংক্রান্ত ধারা ১৭১ ও ১৭২ (আয়কর আইন, ২০২৩)
#
# ---
#
# ### রেফারেন্স ও সূত্রসমূহ
#
# - **আয়কর আইন, ২০২৩**
#   - ধারা ২৬৫: রিটার্ন দাখিলের প্রমাণ প্রদর্শন
#   - ধারা ১৭১: রিটার্ন দাখিলের সময়
#   - ধারা ১৭২: রিটার্ন দাখিলের জন্য নোটিশ
#   - ধারা ২৬৬: রিটার্ন দাখিল ব্যর্থতার জরিমানা
# - **TDS Rules, ২০২৪**
#   - বিধি ১৫: উৎস কর কর্তন রিটার্ন দাখিলের প্রাপ্তি স্বীকারপত্র
# - **উৎস কর কর্তন রিটার্ন দাখিলের প্রাপ্তি স্বীকারপত্রের নমুনা** (TDS Rules, ২০২৪, পৃষ্ঠা ৬৩)
#
# ---
#
# আপনি যদি আরও বিস্তারিত বা নির্দিষ্ট কোনো দিক নিয়ে সাহায্য চান, আমি প্রস্তুত আছি। আশা করি এই তথ্য আপনার কাজকে সহজ করবে এবং ক্লায়েন্টের চাহিদা পূরণে সহায়ক হবে।
#
# ধন্যবাদান্তে,
# আপনার আইনি সহকারী
# (বঙ্গবন্ধু আইনি সহায়তা)
# [{'index': 'acts', 'id': '9d46813f-39f1-4f61-86e8-7fca43e4ffce', 'title': 'আয়কর আইন', 'date': None, 'score': 0.337217361, 'url': None}, {'index': 'acts', 'id': '44619059-b3a2-4ef2-bb42-bae4e11b06d2', 'title': None, 'date': None, 'score': 0.282390594, 'url': None}, {'index': 'acts', 'id': '0327cb85-c72e-4b8f-9144-64f3f0b497b5', 'title': 'আয়কর আইন', 'date': None, 'score': 0.27791214, 'url': None}, {'index': 'acts', 'id': 'a8350525-844b-4549-833b-55b8e0b99198', 'title': None, 'date': None, 'score': 0.270834953, 'url': None}, {'index': 'acts', 'id': 'ba03ba3a-286e-4550-b00d-166730703785', 'title': None, 'date': None, 'score': 0.263139725, 'url': None}, {'index': 'rules', 'id': 'e6fc5d1b-3959-441c-8969-1b78179af371', 'title': 'TDS Rules, 2024', 'date': None, 'score': 0.260393173, 'url': None}, {'index': 'acts', 'id': '1fa6503c-3e81-4226-9d33-f84322260c1e', 'title': None, 'date': None, 'score': 0.254070282, 'url': None}, {'index': 'ordinances', 'id': '950dcfcc-84b1-4876-987c-8da682e7b894', 'title': None, 'date': None, 'score': 0.254013062, 'url': None}, {'index': 'rules', 'id': '0743d1aa-6154-42f5-af41-3acdbc1f8d62', 'title': 'Income Tax Alternative Dispute Resolution Rules, 2024', 'date': None, 'score': 0.244585037, 'url': None}, {'index': 'ordinances', 'id': 'ca087752-6b53-4b2e-add4-2f1a0e187da9', 'title': None, 'date': None, 'score': 0.231206909, 'url': None}, {'index': 'rules', 'id': '10059e25-2f29-4c36-a0c0-f3e36df50b26', 'title': 'Income Tax Alternative Dispute Resolution Rules, 2024', 'date': None, 'score': 0.214921951, 'url': None}, {'index': 'rules', 'id': 'ac04824c-b339-4c6c-8257-2ea020c791f2', 'title': 'TDS Rules, 2024', 'date': None, 'score': 0.214395538, 'url': None}]

# %%
out = run_legal_query(
    "ইভেন্ট ম্যানেজমেন্ট সেবার কমিশন ফীর উপর টি ডি এস রেট কতো?",
    use_web=True
)
print(out.final_answer)
print(out.citations)
# Out:
# ইভেন্ট ম্যানেজমেন্ট সেবার কমিশন ফীর উপর উৎসে কর (TDS) হার সম্পর্কে বিস্তারিত:
#
# ---
#
# ### ১. সমস্যা ও প্রাসঙ্গিক সংজ্ঞা
#
# **টি ডি এস (TDS)** বা উৎসে কর হলো এমন একটি কর ব্যবস্থা যেখানে কোনো অর্থ পরিশোধের সময়ই কর কর্তন করে সরকারকে জমা দিতে হয়। এটি কর আদায়ের একটি কার্যকর পদ্ধতি, যা আয়কর আইন ও সংশ্লিষ্ট বিধিমালা দ্বারা নিয়ন্ত্রিত।
#
# **ইভেন্ট ম্যানেজমেন্ট সেবা** বলতে বোঝায় বিভিন্ন ধরণের ইভেন্ট (যেমন: সম্মেলন, প্রদর্শনী, সাংস্কৃতিক অনুষ্ঠান, কর্পোরেট ইভেন্ট ইত্যাদি) পরিচালনা ও ব্যবস্থাপনার সেবা। এই সেবার জন্য কমিশন ফি বা পারিশ্রমিক প্রদান করা হলে, সেই অর্থের উপর উৎসে কর কর্তন বাধ্যতামূলক।
#
# ---
#
# ### ২. আইনি উৎস ও বিধিমালা
#
# - **উৎসে কর বিধিমালা, ২০২৪ (TDS Rules, 2024)** — সর্বশেষ সংশোধিত (২ জুন ২০২৪) বিধিমালা অনুযায়ী, বিধি ৫ এর সারণীতে ইভেন্ট ম্যানেজমেন্টসহ ব্যবস্থাপনা সেবার কমিশন ফীর উপর ২০% হার দিয়ে উৎসে কর কর্তন করতে হবে।
#   - **সূত্র:**
#     - TDS Rules, 2024, বিধি ৫, সারণী-৫-১
#     - [Rules\12. TDS Rules, 2024 (Amendment 02 June 25)_complete_transcription.txt](#) (দেখুন চাঙ্ক আইডি: 7d50359f-4305-4973-a823-65949b300e1c)
#
# - **আয়কর আইন, ২০২৩** — সাধারণত কমিশন, ডিসকাউন্ট, ফি ইত্যাদির উপর ১০% হার দিয়ে কর কর্তন করার বিধান থাকলেও, নির্দিষ্ট সেবা ভিত্তিক বিধিমালা (যেমন TDS Rules, 2024) প্রাধান্য পায়।
#   - **সূত্র:**
#     - Income Tax Act, 2023, ধারা ৯৪
#     - [Doc\04. Income Tax Act, 2023 (22 June 2023)__split__4.txt](#) (চাঙ্ক আইডি: 47a8de66-467d-40a8-b744-7a3551f9aa14)
#
# ---
#
# ### ৩. বিস্তারিত হার ও প্রযোজ্যতা
#
# | ক্রমিক নং | পরিশোধের বর্ণনা                         | টি ডি এস হার  |
# |------------|----------------------------------------|---------------|
# | ৯          | ইভেন্ট ম্যানেজমেন্টসহ ব্যবস্থাপনা সেবা | ২০%           |
# | ১০         | কমিশন (সাধারণ)                        | ২০%           |
#
# - অর্থাৎ, ইভেন্ট ম্যানেজমেন্ট সেবার কমিশন ফীর উপর ২০% হারে উৎসে কর কর্তন বাধ্যতামূলক।
# - এই হার TDS Rules, 2024 এর সর্বশেষ সংশোধনী (২ জুন ২০২৪) অনুযায়ী প্রযোজ্য।
#
# ---
#
# ### ৪. অন্যান্য প্রাসঙ্গিক তথ্য
#
# - **বিদেশ থেকে প্রাপ্ত সেবা ফি**: বিদেশ থেকে প্রাপ্ত সেবা ফি বা কমিশনেও সাধারণত ১০% TDS প্রযোজ্য, তবে ইভেন্ট ম্যানেজমেন্ট সেবা যদি বাংলাদেশে প্রদত্ত হয়, তাহলে ২০% হার প্রযোজ্য হবে।
#   - Income Tax Act, 2023, ধারা ১২৪ (চাঙ্ক আইডি: 97d13207-fb04-4013-aa83-c4ad598b31d3)
#
# - **কমিশন, ডিসকাউন্ট, ফি ইত্যাদি**: সাধারণ কমিশন ফি-র উপর ১০% TDS ধার্য থাকলেও, সেবা ভিত্তিক নির্দিষ্ট বিধিমালা (যেমন ইভেন্ট ম্যানেজমেন্ট) ২০% হার নির্ধারণ করেছে।
#
# ---
#
# ### ৫. সারসংক্ষেপ ও উপসংহার
#
# - **ইভেন্ট ম্যানেজমেন্ট সেবার কমিশন ফীর উপর TDS হার:**
#   - **২০%** (উৎসে কর বিধিমালা, ২০২৪, বিধি ৫ এর সারণী অনুযায়ী)
# - **আইনি প্রাধান্য:** TDS Rules, 2024 এর নির্দিষ্ট সারণী আইনের সাধারণ ধারার (Income Tax Act, 2023) ওপর প্রাধান্য পায়।
# - **সর্বশেষ সংশোধনী:** ২ জুন ২০২৪ তারিখে প্রযোজ্য।
# - **প্রযোজ্য কর্তৃপক্ষ:** বাংলাদেশ রাজস্ব বোর্ড (NBR) ও সংশ্লিষ্ট কর কর্তৃপক্ষ।
#
# ---
#
# ### ৬. রেফারেন্স ও সূত্র
#
# - **TDS Rules, 2024 (Amendment 02 June 2024)**
#   - বিধি ৫, সারণী-৫-১: ইভেন্ট ম্যানেজমেন্টসহ ব্যবস্থাপনা সেবা ২০% TDS
#   - [NBR Official Website](https://nbr.gov.bd) (সংশ্লিষ্ট SRO ডাউনলোড ও বিস্তারিত তথ্যের জন্য)
#
# - **Income Tax Act, 2023**
#   - ধারা ৯৩-৯৪: কমিশন ও ফি-র উপর কর কর্তন
#   - ধারা ১২৪: বিদেশ থেকে প্রাপ্ত সেবা ফি-র উপর কর কর্তন
#
# ---
#
# ### বন্ধুত্বপূর্ণ পরামর্শ
#
# ইভেন্ট ম্যানেজমেন্ট সেবার কমিশন ফী প্রদানের সময় ২০% TDS কর্তন নিশ্চিত করুন এবং সংশ্লিষ্ট কর কর্তৃপক্ষের নির্দেশনা অনুযায়ী কর জমা দিন। কর পরিশোধের সঠিকতা ও সময়মতো কর কর্তনের মাধ্যমে ভবিষ্যতে জরিমানা ও আইনি জটিলতা এড়ানো সম্ভব হবে।
#
# ---
#
# আপনার যদি আরও বিস্তারিত বা নির্দিষ্ট পরিস্থিতি সম্পর্কে প্রশ্ন থাকে, তাহলে জানাবেন। আমি সাহায্য করতে প্রস্তুত আছি। ধন্যবাদ!
# [{'index': 'rules', 'id': '7d50359f-4305-4973-a823-65949b300e1c', 'title': 'TDS Rules, 2024', 'date': None, 'score': 0.411707908, 'url': None}, {'index': 'rules', 'id': 'd9d26998-8d2b-4f38-a701-c33d144aa490', 'title': 'TDS Rules, 2024', 'date': None, 'score': 0.390619278, 'url': None}, {'index': 'rules', 'id': 'b9aea42a-67ed-4392-96ea-c723166c0fae', 'title': 'TDS Rules, 2024', 'date': None, 'score': 0.378012687, 'url': None}, {'index': 'acts', 'id': '7ed407f0-97bd-46e3-9661-6ecfbcb4db2a', 'title': None, 'date': None, 'score': 0.359457016, 'url': None}, {'index': 'acts', 'id': '47a8de66-467d-40a8-b744-7a3551f9aa14', 'title': None, 'date': None, 'score': 0.354093552, 'url': None}, {'index': 'acts', 'id': '5ad37505-6331-40fb-8561-41bb93cdc818', 'title': None, 'date': None, 'score': 0.350381851, 'url': None}, {'index': 'rules', 'id': '27b34c05-09c2-47cc-8051-88950a659584', 'title': 'TDS Rules, 2024', 'date': None, 'score': 0.340470344, 'url': None}, {'index': 'acts', 'id': '97d13207-fb04-4013-aa83-c4ad598b31d3', 'title': None, 'date': None, 'score': 0.339865714, 'url': None}, {'index': 'acts', 'id': '71c9e575-b8d5-48b4-867f-b718e328fb65', 'title': 'আয়কর আইন', 'date': None, 'score': 0.338089, 'url': None}, {'index': 'rules', 'id': '8c0d4ee2-eed6-4fdf-ba3a-8e24a7a79be1', 'title': 'উৎসে কর বিধিমালা, ২০২৪', 'date': None, 'score': 0.337159187, 'url': None}, {'index': 'rules', 'id': '119915a9-7db3-4fb3-85ac-c19c4de18182', 'title': 'উৎসে কর বিধিমালা, ২০২৪', 'date': None, 'score': 0.336048126, 'url': None}, {'index': 'ordinances', 'id': '34473f1e-433c-468d-be31-7ca9910c97fe', 'title': None, 'date': None, 'score': 0.333662033, 'url': None}]

# %%
out = run_legal_query(
    "",
    use_web=True
)
print(out.final_answer)
print(out.citations)

# %%
out = run_legal_query(
    "How can I check whether my employer is deducting excess income tax or not?",
    use_web=True
)
print(out.final_answer)
print(out.citations)
# Out:
# আপনি কীভাবে যাচাই করবেন যে আপনার নিয়োগকর্তা (employer) আপনার আয় থেকে অতিরিক্ত আয়কর কর্তন করছে কিনা, সে বিষয়ে বিস্তারিত নির্দেশনা নিচে দেওয়া হলো:
#
# ---
#
# ### ১. উৎসে কর কর্তনের সনদপত্র (TDS Certificate) সংগ্রহ করুন
# - **তফসিল ২ অনুযায়ী** (TDS Rules, ২০২৪, বিধি ১১(১)) আপনার নিয়োগকর্তা কর্তৃক কর্তিত আয়কর সম্পর্কিত একটি **“উৎসে কর কর্তন/সংগ্রহের সনদপত্র”** প্রদান করা বাধ্যতামূলক।
# - এই সনদপত্রে থাকবে:
#   - নিয়োগকর্তার নাম ও ঠিকানা
#   - আপনার নাম, পদবী ও টিআইএন (TIN)
#   - বেতন, ভাতা ও অন্যান্য অর্থ প্রদানের বিস্তারিত
#   - কর্তিত করের পরিমাণ
#   - কর সরকারী কোষাগারে জমা দেওয়ার তথ্য
# - সনদপত্র পাওয়ার মাধ্যমে আপনি জানতে পারবেন কত টাকা কর কর্তন হয়েছে এবং তা সরকারে জমা হয়েছে কিনা।
# - **সূত্র:** [TDS Rules, 2024 - তফসিল ২ (বিধি ১১(১))](https://nbr.gov.bd)
#
# ---
#
# ### ২. আপনার আয়ের উপর ভিত্তি করে কর নিরূপণ করুন
# - আপনার মোট আয় ও করযোগ্য আয় নিরূপণ করুন, যা আয়কর আইন, ২০২৩ এর ধারা ২৬ অনুযায়ী নির্ধারিত হয়।
# - আয়কর আইন, ২০২৩ অনুযায়ী আপনার আয়ের উৎস, করযোগ্য আয় ও কর হার সম্পর্কে সঠিক ধারণা নিন।
# - আপনার আয়ের উপর প্রযোজ্য কর হার ও কর রেয়াত (যদি থাকে) বিবেচনা করে মোট কর নিরূপণ করুন।
# - **সূত্র:** [Income Tax Act, 2023 - Section 26](https://nbr.gov.bd)
#
# ---
#
# ### ৩. কর কর্তনের পরিমাণের সাথে আপনার হিসাব মিলিয়ে দেখুন
# - আপনার হিসাব অনুযায়ী করের পরিমাণ ও নিয়োগকর্তার কর্তিত করের পরিমাণ তুলনা করুন।
# - যদি নিয়োগকর্তার কর্তিত কর আপনার হিসাবের চেয়ে বেশি হয়, তাহলে অতিরিক্ত কর কর্তন হয়েছে বলে ধারণা করা যাবে।
#
# ---
#
# ### ৪. কর রিটার্ন দাখিল করুন এবং অতিরিক্ত কর ফেরত দাবি করুন
# - আয়কর আইন, ২০২৩ এর ধারা ১৭৭ অনুযায়ী, আপনি মাসিক বা বাৎসরিক কর রিটার্ন দাখিল করবেন।
# - রিটার্ন দাখিলের সময় আপনার আয়, কর কর্তন সনদপত্র, কর রেয়াত ও অন্যান্য তথ্য সঠিকভাবে উপস্থাপন করুন।
# - অতিরিক্ত কর কর্তন হলে, আপনি কর রিটার্নের মাধ্যমে সেই অতিরিক্ত কর ফেরত (refund) দাবি করতে পারবেন।
# - **সূত্র:** [Income Tax Act, 2023 - Section 177](https://nbr.gov.bd)
#
# ---
#
# ### ৫. অতিরিক্ত কর পরিশোধের ক্ষেত্রে সুদ পাওয়ার অধিকার
# - আয়কর আইন, ২০২৩ এর ধারা ১৬১ অনুযায়ী, যদি আপনি কোনো অর্থবর্ষে অতিরিক্ত অগ্রিম কর পরিশোধ করে থাকেন, তাহলে সরকার আপনাকে বার্ষিক ১০% হারে সুদ প্রদান করবে।
# - অর্থাৎ, অতিরিক্ত কর কর্তনের কারণে আপনি ক্ষতিগ্রস্ত হলে সুদসহ ফেরত পাওয়ার সুযোগ রয়েছে।
# - **সূত্র:** [Income Tax Act, 2023 - Section 161](https://nbr.gov.bd)
#
# ---
#
# ### ৬. সর্বশেষ সংশোধনী ও নিয়মাবলী অনুসরণ করুন
# - জাতীয় রাজস্ব বোর্ডের সর্বশেষ **SRO ২৪৮-আইন/আয়কর-৪২/২০২৪** (২৭ জুন ২০২৪ তারিখে জারি) অনুযায়ী উৎসে কর বিধিমালা, ২০২৪ সংশোধিত হয়েছে।
# - এই সংশোধনীতে কর কর্তনের হার ও সনদপত্র প্রদানের নিয়মাবলী স্পষ্ট করা হয়েছে।
# - নিয়মিত এই ধরনের সরকারি প্রজ্ঞাপন ও SRO গুলো পর্যবেক্ষণ করুন।
# - **সূত্র:** [SRO ২৪৮-আইন/আয়কর-৪২/২০২৪ (NBR)](https://www.bgpress.gov.bd)
#
# ---
#
# ### সংক্ষিপ্ত পরামর্শ
# - আপনার নিয়োগকর্তার কাছ থেকে **TDS সনদপত্র** (তফসিল ২) অবশ্যই সংগ্রহ করুন।
# - নিজের আয়ের ভিত্তিতে কর নিরূপণ করে কর্তিত করের সাথে মিলিয়ে দেখুন।
# - কর রিটার্ন সময় সঠিক তথ্য দিয়ে অতিরিক্ত কর ফেরত দাবি করুন।
# - প্রয়োজনে একজন পেশাদার কর পরামর্শদাতার সাহায্য নিন।
#
# ---
#
# ### উপসংহার
# আপনার নিয়োগকর্তা কতটুকু আয়কর কর্তন করেছে তা যাচাই করার সবচেয়ে নির্ভরযোগ্য উপায় হলো **উৎসে কর কর্তনের সনদপত্র (TDS Certificate)** সংগ্রহ এবং আপনার নিজস্ব কর হিসাবের সাথে মিলিয়ে দেখা। আয়কর আইন, ২০২৩ ও সংশ্লিষ্ট বিধিমালা অনুযায়ী কর রিটার্ন দাখিলের মাধ্যমে অতিরিক্ত কর ফেরত পাওয়ার সুযোগ রয়েছে এবং অতিরিক্ত করের উপর সুদ পাওয়ার বিধানও রয়েছে।
#
# ---
#
# আপনার যদি আরও বিস্তারিত বা নির্দিষ্ট প্রশ্ন থাকে, আমি সাহায্য করতে প্রস্তুত আছি।
#
# ---
#
# **সূত্রসমূহ:**
# - [TDS Rules, 2024 (জাতীয় রাজস্ব বোর্ড)](https://nbr.gov.bd)
# - [Income Tax Act, 2023 (বাংলাদেশ)](https://nbr.gov.bd)
# - [SRO ২৪৮-আইন/আয়কর-৪২/২০২৪ (NBR)](https://www.bgpress.gov.bd)
#
# ---
#
# আশা করি এই তথ্য আপনার জন্য সহায়ক হবে। ধন্যবাদ!
# [{'index': 'rules', 'id': '31afd174-bd43-461b-8f1c-4d140ffa35e1', 'title': 'TDS Rules, 2024', 'date': None, 'score': 0.337396622, 'url': None}, {'index': 'rules', 'id': '60bf82ee-892a-498f-adcb-efafb809d3f7', 'title': 'উৎসে কর বিধিমালা', 'date': None, 'score': 0.274924308, 'url': None}, {'index': 'rules', 'id': 'ace79d9d-5974-4fdd-985b-27e4320227c3', 'title': 'TDS Rules, 2024', 'date': None, 'score': 0.253047973, 'url': None}, {'index': 'rules', 'id': '78881579-dd8f-4e4a-bc6e-163e932d01bc', 'title': 'TDS Rules, 2024', 'date': None, 'score': 0.250310898, 'url': None}, {'index': 'rules', 'id': '1bea8913-8a84-40ea-962a-557000a8b52e', 'title': 'TDS Rules, 2024', 'date': None, 'score': 0.24012658, 'url': None}, {'index': 'rules', 'id': '95a7e453-e66c-4c3b-8255-3cc3ce67bbde', 'title': None, 'date': None, 'score': 0.234741226, 'url': None}, {'index': 'acts', 'id': 'b786a4ab-993c-495b-9e47-259ca461ef70', 'title': None, 'date': None, 'score': 0.196090713, 'url': None}, {'index': 'acts', 'id': 'be2fe7c2-f49c-457c-9c65-ccc1eea1bf15', 'title': None, 'date': None, 'score': 0.191225052, 'url': None}, {'index': 'ordinances', 'id': 'cd96e79b-6de8-47ea-9b8d-4e63628e7683', 'title': None, 'date': None, 'score': 0.190847397, 'url': None}, {'index': 'acts', 'id': 'cd4e957c-7c7c-4d45-b8b9-2df87a6f36a2', 'title': None, 'date': None, 'score': 0.190086335, 'url': None}, {'index': 'acts', 'id': 'deb627f0-c1cd-47b6-bacf-bcaba2cb6ac5', 'title': 'আয়কর আইন', 'date': None, 'score': 0.189833641, 'url': None}, {'index': 'acts', 'id': '36cc286d-c68b-416b-b947-c07d32f8a8dd', 'title': 'আয়কর আইন', 'date': None, 'score': 0.189833641, 'url': None}]

# %%
out = run_legal_query(
    "What is the tax rate for capital gain for individuals?",
    use_web=True
)
print(out.final_answer)
print(out.citations)
# Out:
# আপনার প্রশ্ন ছিল: **ব্যক্তিদের জন্য মূলধন লাভ (Capital Gain) করের হার কত?**
#
# ### সংক্ষিপ্ত উত্তর:
# বর্তমানে প্রাপ্ত আইন ও বিধিমালা অনুসারে, বাংলাদেশে ব্যক্তিদের জন্য **মূলধন লাভ করের নির্দিষ্ট হার সরাসরি আইন বা বিধিমালায় স্পষ্টভাবে উল্লেখিত নেই**। তবে, আয়কর আইন, ২০২৩ এবং পরবর্তী ফাইন্যান্স অধ্যাদেশ ও জাতীয় রাজস্ব বোর্ডের (NBR) উৎসে কর বিধিমালা অনুযায়ী ব্যক্তিদের করযোগ্য আয়ের উপর সারচার্জের হার এবং বিভিন্ন উৎস থেকে আয়ের উপর উৎসে কর (TDS) হার নির্ধারিত আছে, যা মূলধন লাভ করের হার নয় বরং আয়ের উপর প্রযোজ্য অন্যান্য করের হার।
#
# ---
#
# ### বিস্তারিত ব্যাখ্যা ও প্রাসঙ্গিক আইন:
#
# ১. **আয়কর আইন, ২০২৩ (Income Tax Act, 2023)**
#    - আইন অনুযায়ী, ব্যক্তির মোট আয়ের মধ্যে বিভিন্ন উৎস থেকে প্রাপ্ত আয় অন্তর্ভুক্ত হয় (ধারা ২৬)।
#    - কিন্তু মূলধন লাভ করের নির্দিষ্ট হার বা বিধান সরাসরি উল্লিখিত হয়নি।
#    - [আয়কর আইন, ২০২৩ - ধারা ২৬](https://www.bgpress.gov.bd) (উল্লেখযোগ্য অংশ সংক্ষেপে উপরে দেওয়া হয়েছে)
#
# ২. **ফাইন্যান্স অধ্যাদেশ, ২০২৫ (Finance Ordinance, 2025)**
#    - ১ জুলাই ২০২৬ থেকে কার্যকর, এই অধ্যাদেশে ব্যক্তিদের করযোগ্য আয়ের উপর সারচার্জের হার নির্ধারণ করা হয়েছে, যা মূলধন লাভ করের হার নয় বরং করযোগ্য আয়ের উপর অতিরিক্ত কর।
#    - সারচার্জের হার নিম্নরূপ (তফসিল ২, অনুচ্ছেদ ক):
#      - নিট পরিসম্পদের পরিমাণ ৪ কোটি টাকা পর্যন্ত: ০%
#      - ৪ কোটি থেকে ১০ কোটি টাকার মধ্যে: ১০%
#      - ১০ কোটি থেকে ২০ কোটি টাকার মধ্যে: ২০%
#      - ২০ কোটি থেকে ৫০ কোটি টাকার মধ্যে: ৩০%
#      - ৫০ কোটি টাকার অধিক: ৩৫%
#    - [Finance Ordinance, 2025 (অধ্যাদেশ নং ২৮, ২০২৫)](https://www.bgpress.gov.bd)
#
# ৩. **জাতীয় রাজস্ব বোর্ডের উৎসে কর বিধিমালা, ২০২৪ (TDS Rules, 2024) ও সংশোধনসমূহ**
#    - বিভিন্ন পেশাদার সেবা, উপদেষ্টা ফি, কমিশন ইত্যাদির উপর উৎসে কর হার ২০% নির্ধারিত আছে।
#    - তবে, মূলধন লাভ করের জন্য আলাদা কোনো উৎসে কর হার বা বিধান নেই।
#    - [জাতীয় রাজস্ব বোর্ড প্রজ্ঞাপন এস.আর.ও. নং ২৪৮-আইন/আয়কর-৪২/২০২৪](https://www.bgpress.gov.bd)
#
# ---
#
# ### সারাংশ ও উপসংহার:
#
# - **মূলধন লাভ করের হার আইন বা বিধিমালায় স্পষ্টভাবে উল্লেখিত নয়।**
# - ব্যক্তিদের করযোগ্য আয়ের উপর সারচার্জের হার ফাইন্যান্স অধ্যাদেশ, ২০২৫ অনুযায়ী ০% থেকে ৩৫% পর্যন্ত নির্ধারিত।
# - বিভিন্ন পেশাদার সেবা ও অন্যান্য আয়ের উৎসে উৎসে কর (TDS) হার ২০% পর্যন্ত হতে পারে, কিন্তু এটি মূলধন লাভ কর নয়।
# - মূলধন লাভ করের হার নির্ধারণ বা সংশোধন হলে তা জাতীয় রাজস্ব বোর্ড ও অর্থ মন্ত্রণালয়ের মাধ্যমে প্রকাশিত হবে।
#
# ---
#
# ### প্রাসঙ্গিক সূত্রসমূহ:
#
# | আইন/বিধি/অধ্যাদেশ | উল্লেখযোগ্য ধারা/অনুচ্ছেদ | কার্যকর তারিখ | লিঙ্ক (সরকারি) |
# |--------------------|--------------------------|---------------|-----------------|
# | আয়কর আইন, ২০২৩ | ধারা ২৬ (মোট আয়ের আওতা) | ২০২৩-০৬-২২ | [bgpress.gov.bd](https://www.bgpress.gov.bd) |
# | ফাইন্যান্স অধ্যাদেশ, ২০২৫ | তফসিল ২ - সারচার্জের হার | ২০২৬-০৭-০১ | [bgpress.gov.bd](https://www.bgpress.gov.bd) |
# | উৎসে কর বিধিমালা, ২০২৪ (সংশোধন) | বিধি ৩, ৫ (TDS হার) | ২০২৪-০৭-০১ | [bgpress.gov.bd](https://www.bgpress.gov.bd) |
#
# ---
#
# ### বন্ধুত্বপূর্ণ পরামর্শ:
# মূলধন লাভ করের হার বা বিধান সম্পর্কে সুনির্দিষ্ট তথ্যের জন্য নিয়মিত জাতীয় রাজস্ব বোর্ডের অফিসিয়াল প্রকাশনা ও গেজেট মনিটর করা উচিত। কারণ কর আইন ও বিধিমালা সময়ে সময়ে পরিবর্তিত হতে পারে।
#
# ---
#
# আপনার যদি আরও বিস্তারিত বা নির্দিষ্ট কোনো দিক সম্পর্কে প্রশ্ন থাকে, আমি সাহায্য করতে প্রস্তুত আছি। ধন্যবাদ!
# [{'index': 'ordinances', 'id': 'cd96e79b-6de8-47ea-9b8d-4e63628e7683', 'title': None, 'date': None, 'score': 0.311403245, 'url': None}, {'index': 'rules', 'id': '60bf82ee-892a-498f-adcb-efafb809d3f7', 'title': 'উৎসে কর বিধিমালা', 'date': None, 'score': 0.279537201, 'url': None}, {'index': 'rules', 'id': '7d50359f-4305-4973-a823-65949b300e1c', 'title': 'TDS Rules, 2024', 'date': None, 'score': 0.262807846, 'url': None}, {'index': 'ordinances', 'id': '789e1389-9e13-47e0-97d7-8f9e31e22e3b', 'title': None, 'date': None, 'score': 0.255275726, 'url': None}, {'index': 'rules', 'id': '95a7e453-e66c-4c3b-8255-3cc3ce67bbde', 'title': None, 'date': None, 'score': 0.239156723, 'url': None}, {'index': 'rules', 'id': '3f44f5b9-f493-4eba-9762-b539c2485e2b', 'title': 'উৎসে কর বিধিমালা', 'date': None, 'score': 0.238271683, 'url': None}, {'index': 'rules', 'id': 'c3809a09-6e47-4859-a471-71b09d68a42c', 'title': 'উৎসে কর বিধিমালা', 'date': None, 'score': 0.238203019, 'url': None}, {'index': 'rules', 'id': '88b564f8-a0e7-481f-b03f-ef469e0ee733', 'title': 'উৎসে কর বিধিমালা', 'date': None, 'score': 0.220380753, 'url': None}, {'index': 'ordinances', 'id': '0b48de4a-0e50-42d5-880a-19c1940de775', 'title': None, 'date': None, 'score': 0.21641922, 'url': None}, {'index': 'acts', 'id': 'deb627f0-c1cd-47b6-bacf-bcaba2cb6ac5', 'title': 'আয়কর আইন', 'date': None, 'score': 0.214855164, 'url': None}, {'index': 'acts', 'id': '36cc286d-c68b-416b-b947-c07d32f8a8dd', 'title': 'আয়কর আইন', 'date': None, 'score': 0.214855164, 'url': None}, {'index': 'acts', 'id': '461a13d0-f133-421b-b5fe-13f06aff5576', 'title': 'আয়কর আইন', 'date': None, 'score': 0.212564439, 'url': None}]
