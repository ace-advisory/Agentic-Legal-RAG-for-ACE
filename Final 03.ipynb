# %%
from __future__ import annotations
import os
import json
from typing import Any, Dict, List, Optional, TypedDict, Literal

from pydantic import BaseModel, Field

# LangChain / OpenAI / Pinecone
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from pinecone import Pinecone

# Web search (optional)
import requests

# LangGraph
from langgraph.graph import StateGraph, START, END
from langgraph.checkpoint.memory import MemorySaver

# %%
DEFAULT_INDEXES: Dict[str, str] = {
    "acts": "act-agentic-chunking",
    "rules": "rules-agentic-chunking",
    "sro": "sro-agentic-chunking",
    "ordinances": "ordinance-agentic-chunking",
}

ALLOWED_DOMAINS_DEFAULT = [
    "bdlaws.minlaw.gov.bd",
    "nbr.gov.bd",
    "mof.gov.bd",
    "dpp.gov.bd",
    "cabinet.gov.bd",
    "bangladesh.gov.bd",
]

# %%
class EntityHierarchy(TypedDict, total=False):
    part: Optional[str]
    chapter: Optional[str]
    section: Optional[str]
    subsection: Optional[str]
    clause: Optional[str]

class Entities(TypedDict, total=False):
    law_name: Optional[str]
    law_year: Optional[str]
    hierarchy: EntityHierarchy

class Hit(TypedDict, total=False):
    index: Literal["acts", "rules", "sro", "ordinances", "web"]
    id: str
    score: float
    text: str
    metadata: Dict[str, Any]

class Plan(TypedDict, total=False):
    need_rules: bool
    need_sro: bool
    need_ordinances: bool
    need_web: bool
    targeted_queries: List[str]

class Verification(TypedDict, total=False):
    notes: str
    risk_level: Literal["low", "medium", "high"]
    must_check: List[str]

class RAGState(TypedDict, total=False):
    query: str
    use_web: bool
    entities: Entities
    acts_hits: List[Hit]
    rules_hits: List[Hit]
    sro_hits: List[Hit]
    ordinances_hits: List[Hit]
    web_hits: List[Hit]
    stage1_answer: str
    citations_stage1: List[Dict[str, Any]]
    plan: Plan
    merged_hits: List[Hit]
    verification: Verification
    final_answer: str
    citations: List[Dict[str, Any]]

class Deps(BaseModel):
    indexes: Dict[str, str] = Field(default_factory=lambda: DEFAULT_INDEXES.copy())
    embedding_model: str = "text-embedding-3-large"
    model_fast: str = "gpt-5-mini"
    model_reason: str = "gpt-5"
    allowed_domains: List[str] = Field(default_factory=lambda: ALLOWED_DOMAINS_DEFAULT.copy())
    tavily_endpoint: str = "https://api.tavily.com/search"

    # runtime clients:
    pc: Any = None
    emb: Any = None
    llm_fast: Any = None
    llm_reason: Any = None

    def init_clients(self) -> None:
        if not os.environ.get("OPENAI_API_KEY"):
            raise RuntimeError("Please set OPENAI_API_KEY")
        if not os.environ.get("PINECONE_API_KEY"):
            raise RuntimeError("Please set PINECONE_API_KEY")
        self.pc = Pinecone(api_key=os.environ.get("PINECONE_API_KEY"))
        self.emb = OpenAIEmbeddings(model=self.embedding_model)
        self.llm_fast = ChatOpenAI(model=self.model_fast, temperature=0.2)
        self.llm_reason = ChatOpenAI(model=self.model_reason, temperature=0.2)

# %%
ENTITIES_PROMPT = ChatPromptTemplate.from_messages([
    ("system", "You are a precise legal entity extractor for Bangladeshi laws. "
               "Extract structured fields from the user query. Respond in strict JSON."),
    ("human",
     "User query:\n{query}\n\n"
     "Return JSON with keys exactly: law_name, law_year, hierarchy.\n"
     "hierarchy must be an object with optional keys: part, chapter, section, subsection, clause.\n"
     "If unknown, leave them null.\n"
     "Return exactly this shape:\n"
     "{{\"law_name\": null, \"law_year\": null, \"hierarchy\": {{\"part\": null, \"chapter\": null, \"section\": null, \"subsection\": null, \"clause\": null}}}}")
])

SYNTH_STAGE1 = ChatPromptTemplate.from_messages([
    ("system",
     "You are a meticulous Bangladeshi legal assistant. Answer using ONLY the ACTS context.\n"
     "Be concise, cite exact sections if visible in context. If unclear, say what else is needed.\n"),
    ("human",
     "User question:\n{query}\n\n"
     "ACTS context (top passages):\n{context}\n\n"
     "Write a short, precise answer in Bangla if the question is Bangla; otherwise in English.\n"
     "Add a one-line 'Next step' if the answer likely depends on Rules/SRO/Ordinances.")
])

ESCALATE_PROMPT = ChatPromptTemplate.from_messages([
    ("system", "You are a policy decider. Return STRICT JSON."),
    ("human",
     "User question:\n{query}\n\n"
     "Initial answer (acts-only):\n{answer}\n\n"
     "Decide if we should search Rules/SRO/Ordinances and possibly the Web.\n"
     "Return JSON EXACTLY in this shape:\n"
     "{{\"need_rules\": true, \"need_sro\": true, \"need_ordinances\": false, \"need_web\": true, \"targeted_queries\": []}}")
])
VERIFY_PROMPT = ChatPromptTemplate.from_messages([
    ("system",
     "You are verifying if any SRO/Gazette has amended or superseded the cited sections. "
     "Respond with STRICT JSON only (no extra text)."),
    ("human",
     "User question:\n{query}\n\n"
     "Context snippets (Acts/Rules/SRO/Web):\n{context}\n\n"
     "Return JSON EXACTLY in this shape:\n"
     "{{\"notes\": \"...\", \"risk_level\": \"low|medium|high\", \"must_check\": [\"...\"]}}")
])

FINAL_SYNTH = ChatPromptTemplate.from_messages([
    ("system",
     "You are a senior Bangladeshi legal assistant. Synthesize a precise, practical answer "
     "using Acts first, then Rules/SRO/Ordinances. Be conservative where uncertainty exists."),
    ("human",
     "User question:\n{query}\n\n"
     "Merged context (top excerpts):\n{context}\n\n"
     "Verification notes:\n{verify}\n\n"
     "Write a final answer (Bangla if the question is Bangla, else English). "
     "Include short bullet citations like [Act §X], [Rule Y], [SRO Z/Year], or a source URL.")
])

# %%
def _strip_json(raw: str) -> str:
    return raw.strip().removeprefix("```json").removesuffix("```").strip("` \n")

def embed(deps: Deps, text: str) -> List[float]:
    return deps.emb.embed_query(text)

def pc_query(deps: Deps, index_name: str, vector: List[float], top_k: int = 10) -> List[Dict[str, Any]]:
    idx = deps.pc.Index(index_name)
    res = idx.query(vector=vector, top_k=top_k, include_metadata=True)
    return res.get("matches", [])

def build_queries(state: RAGState) -> List[str]:
    q = state["query"]
    ents = state.get("entities", {}) or {}
    law_name = ents.get("law_name")
    law_year = ents.get("law_year")
    hier = ents.get("hierarchy", {}) or {}

    seeds = [q]
    if law_name:
        seeds += [
            f"{law_name} {law_year or ''}".strip(),
            f"{law_name} consolidated version latest amendment",
            f"{law_name} Rules Regulations",
        ]
    if hier.get("section"):
        seeds.append(f"{law_name or ''} section {hier['section']}".strip())
    if hier.get("subsection"):
        seeds.append(f"{law_name or ''} subsection {hier['subsection']}".strip())
    if hier.get("clause"):
        seeds.append(f"{law_name or ''} clause {hier['clause']}".strip())

    out, seen = [], set()
    for s in seeds:
        s = " ".join(str(s).split())
        if s and s.lower() not in seen:
            out.append(s); seen.add(s.lower())
    return out

def retrieve_from_index(deps: Deps, index_key: str, state: RAGState, top_k: int = 8) -> List[Hit]:
    index_name = deps.indexes[index_key]
    hits: List[Hit] = []
    for q in build_queries(state):
        vec = embed(deps, q)
        try:
            matches = pc_query(deps, index_name, vec, top_k=top_k)
        except Exception as e:
            print(f"[WARN] Pinecone query failed for {index_name}: {e}")
            continue
        for m in matches:
            md = m.get("metadata", {}) or {}
            txt = md.get("page_content") or md.get("text") or ""
            score = float(m.get("score", 0.0))
            hits.append({
                "index": index_key,
                "id": m.get("id", ""),
                "score": score,
                "text": txt,
                "metadata": {**md, "_index_name": index_name, "_query": q}
            })
    return hits

def mk_citation(h: Hit) -> Dict[str, Any]:
    md = h.get("metadata", {}) or {}
    title = md.get("title") or md.get("doc_title") or md.get("rules_name") or md.get("act_title") or ""
    link = md.get("source_url") or md.get("url") or md.get("source") or md.get("pdf_url") or ""
    location = md.get("section") or md.get("rule") or md.get("clause") or ""
    return {
        "index": h.get("index"),
        "id": h.get("id"),
        "title": title,
        "location": location,
        "score": h.get("score"),
        "link": link,
    }

# %%
def node_extract_entities(state: RAGState, deps: Deps) -> RAGState:
    chain = ENTITIES_PROMPT | deps.llm_fast | StrOutputParser()
    raw = chain.invoke({"query": state["query"]})
    try:
        data = json.loads(_strip_json(raw))
    except Exception:
        data = {"law_name": None, "law_year": None, "hierarchy": {}}
    hier = data.get("hierarchy") or {}
    for k in ["part", "chapter", "section", "subsection", "clause"]:
        hier[k] = hier.get(k)
    return {"entities": {"law_name": data.get("law_name"), "law_year": data.get("law_year"), "hierarchy": hier}}

def node_retrieve_acts(state: RAGState, deps: Deps) -> RAGState:
    return {"acts_hits": retrieve_from_index(deps, "acts", state, top_k=10)}

def node_synthesize_stage1(state: RAGState, deps: Deps) -> RAGState:
    acts_sorted = sorted(state.get("acts_hits", []), key=lambda h: h["score"], reverse=True)[:8]
    context = "\n\n---\n\n".join(h["text"][:1800] for h in acts_sorted)
    chain = SYNTH_STAGE1 | deps.llm_reason | StrOutputParser()
    answer = chain.invoke({"query": state["query"], "context": context}).strip()
    citations = [mk_citation(h) for h in acts_sorted[:4]]
    return {"stage1_answer": answer, "citations_stage1": citations}

def node_decide_escalation(state: RAGState, deps: Deps) -> RAGState:
    chain = ESCALATE_PROMPT | deps.llm_fast | StrOutputParser()
    raw = chain.invoke({"query": state["query"], "answer": state.get("stage1_answer","")}).strip()
    try:
        plan = json.loads(_strip_json(raw))
    except Exception:
        plan = {
            "need_rules": True, "need_sro": True, "need_ordinances": False,
            "need_web": True, "targeted_queries": []
        }
    return {"plan": plan}

# %%
def node_retrieve_rules(state: RAGState, deps: Deps) -> RAGState:
    plan = state.get("plan", {}) or {}
    if not plan.get("need_rules"):
        return {}
    return {"rules_hits": retrieve_from_index(deps, "rules", state, top_k=8)}

def node_retrieve_sro(state: RAGState, deps: Deps) -> RAGState:
    plan = state.get("plan", {}) or {}
    if not plan.get("need_sro"):
        return {}
    return {"sro_hits": retrieve_from_index(deps, "sro", state, top_k=8)}

def node_retrieve_ordinances(state: RAGState, deps: Deps) -> RAGState:
    plan = state.get("plan", {}) or {}
    if not plan.get("need_ordinances"):
        return {}
    return {"ordinances_hits": retrieve_from_index(deps, "ordinances", state, top_k=8)}

def node_web_search(state: RAGState, deps: Deps) -> RAGState:
    plan = state.get("plan", {}) or {}
    if not (state.get("use_web", True) and plan.get("need_web")):
        return {}
    api_key = os.environ.get("TAVILY_API_KEY")
    if not api_key:
        return {}
    ents = state.get("entities", {}) or {}
    wq = f"{ents.get('law_name') or ''} {ents.get('law_year') or ''} latest SRO site:nbr.gov.bd".strip() or state["query"]
    payload = {
        "api_key": api_key,
        "query": wq,
        "max_results": 6,
        "include_answer": False,
        "include_images": False,
        "include_domains": deps.allowed_domains,
        "search_depth": "advanced",
    }
    hits: List[Hit] = []
    try:
        resp = requests.post(deps.tavily_endpoint, json=payload, timeout=30)
        data = resp.json()
        for i, r in enumerate(data.get("results", [])):
            url = r.get("url", "")
            snippet = r.get("content", "") or r.get("snippet", "")
            title = r.get("title", "") or url
            hits.append({
                "index": "web",
                "id": url,
                "score": 0.5 + (6 - i) * 0.05,
                "text": snippet[:1800],
                "metadata": {"title": title, "source_url": url, "provider": "tavily"}
            })
    except Exception as e:
        print(f"[WARN] Tavily web search failed: {e}")
    return {"web_hits": hits}

# %%
def node_merge_hits(state: RAGState, deps: Deps) -> RAGState:
    merged: List[Hit] = []
    for key in ["acts_hits", "rules_hits", "sro_hits", "ordinances_hits", "web_hits"]:
        src = sorted(state.get(key, []) or [], key=lambda h: h["score"], reverse=True)[:6]
        merged.extend(src)
    seen = set(); uniq: List[Hit] = []
    for h in merged:
        k = (h["index"], h["id"])
        if k in seen: continue
        seen.add(k); uniq.append(h)
    return {"merged_hits": uniq[:18]}

def node_verify_latest(state: RAGState, deps: Deps) -> RAGState:
    ctx = "\n\n---\n\n".join([h["text"][:1600] for h in state.get("merged_hits", [])])
    chain = VERIFY_PROMPT | deps.llm_fast | StrOutputParser()
    raw = chain.invoke({"query": state["query"], "context": ctx}).strip()
    try:
        v = json.loads(_strip_json(raw))
    except Exception:
        v = {"notes": "Verification unavailable", "risk_level": "medium", "must_check": []}
    return {"verification": v}

def node_synthesize_final(state: RAGState, deps: Deps) -> RAGState:
    ctx = "\n\n---\n\n".join([h["text"][:1600] for h in state.get("merged_hits", [])])
    chain = FINAL_SYNTH | deps.llm_reason | StrOutputParser()
    ans = chain.invoke({
        "query": state["query"],
        "context": ctx,
        "verify": json.dumps(state.get("verification", {}), ensure_ascii=False)
    }).strip()
    cites: List[Dict[str, Any]] = []
    for h in (state.get("merged_hits") or [])[:10]:
        c = mk_citation(h)
        if c: cites.append(c)
    return {"final_answer": ans, "citations": cites}

# %%
def route_need_rules(state: RAGState) -> bool:
    return bool(state.get("plan", {}).get("need_rules"))

def route_need_sro(state: RAGState) -> bool:
    return bool(state.get("plan", {}).get("need_sro"))

def route_need_ordinances(state: RAGState) -> bool:
    return bool(state.get("plan", {}).get("need_ordinances"))

def route_need_web(state: RAGState) -> bool:
    return bool(state.get("plan", {}).get("need_web") and state.get("use_web", True))

def build_graph(indexes: Dict[str, str] = None,
                model_fast: str = "gpt-5-mini",
                model_reason: str = "gpt-5",
                embedding_model: str = "text-embedding-3-large",
                allowed_domains: List[str] = None):
    deps = Deps(
        indexes=indexes or DEFAULT_INDEXES,
        model_fast=model_fast,
        model_reason=model_reason,
        embedding_model=embedding_model,
        allowed_domains=allowed_domains or ALLOWED_DOMAINS_DEFAULT
    )
    deps.init_clients()

    g = StateGraph(RAGState)

    # Nodes
    g.add_node("extract_entities", lambda s: node_extract_entities(s, deps))
    g.add_node("retrieve_acts", lambda s: node_retrieve_acts(s, deps))
    g.add_node("synthesize_stage1", lambda s: node_synthesize_stage1(s, deps))
    g.add_node("decide_escalation", lambda s: node_decide_escalation(s, deps))

    # GATED sequential nodes (each checks plan and no-ops if not needed)
    g.add_node("retrieve_rules", lambda s: node_retrieve_rules(s, deps))
    g.add_node("retrieve_sro", lambda s: node_retrieve_sro(s, deps))
    g.add_node("retrieve_ordinances", lambda s: node_retrieve_ordinances(s, deps))
    g.add_node("web_search", lambda s: node_web_search(s, deps))

    g.add_node("merge_hits", lambda s: node_merge_hits(s, deps))
    g.add_node("verify_latest", lambda s: node_verify_latest(s, deps))
    g.add_node("synthesize_final", lambda s: node_synthesize_final(s, deps))

    # Edges (linear)
    g.add_edge(START, "extract_entities")
    g.add_edge("extract_entities", "retrieve_acts")
    g.add_edge("retrieve_acts", "synthesize_stage1")
    g.add_edge("synthesize_stage1", "decide_escalation")

    # Always run in sequence; nodes gate themselves
    g.add_edge("decide_escalation", "retrieve_rules")
    g.add_edge("retrieve_rules", "retrieve_sro")
    g.add_edge("retrieve_sro", "retrieve_ordinances")
    g.add_edge("retrieve_ordinances", "web_search")
    g.add_edge("web_search", "merge_hits")

    g.add_edge("merge_hits", "verify_latest")
    g.add_edge("verify_latest", "synthesize_final")
    g.add_edge("synthesize_final", END)

    # If you want to avoid thread_id requirement, compile without checkpointer:
    # app = g.compile()
    # Otherwise keep MemorySaver and pass thread_id in invoke:
    memory = MemorySaver()
    app = g.compile(checkpointer=memory)
    return app

# %%
def show_result(s: dict):
    """Safely print the final answer, citations, and verification from a LangGraph state dict."""
    print("\n--- FINAL ANSWER ---")
    print(s.get("final_answer", "[no final_answer key — the graph may have ended early]"))

    print("\n--- CITATIONS ---")
    cites = s.get("citations", [])
    if not cites:
        print("[no citations]")
    else:
        for i, c in enumerate(cites, 1):
            print(f"{i}. {c}")

    print("\n--- VERIFICATION ---")
    print(s.get("verification", "[no verification]"))

# %%
app = build_graph(indexes=DEFAULT_INDEXES)

state = app.invoke(
    {
        "query": "ধারা ১৬৫ অনুযায়ী withholding tax rate কত?",
        "use_web": True,
    },
    config={"configurable": {"thread_id": "alif-session-001"}}
)

show_result(state)  # (the helper you already defined)
# Out:
# --- FINAL ANSWER ---
# সংক্ষিপ্ত উত্তর: ধারা ১৬৫ নিজে কোনো “একক” হার দেয় না। আইনে বলা আছে—উৎসে কর “বিধিমালায় নির্ধারিত হারে” কর্তন হবে। তাই হারটি সংশ্লিষ্ট পরিশোধ/সেবা/পণ্য–শ্রেণির উপর নির্ভর করে এবং বর্তমান হারগুলো উৎসে কর বিধিমালা, ২০২৪-এ (সর্বশেষ সংশোধন: ২৭ জুন ২০২৪) সারণী অনুযায়ী প্রযোজ্য। [Act §165], [Rules r.5/Table; SRO 248/2024]
#
# প্রচলিত কিছু হার (উদাহরণ)
# - উপদেষ্টা/পরামর্শক ফি: স্বাভাবিক ব্যক্তি 20%; অন্যান্য ব্যক্তি 10% [Rules r.5/Table; SRO 248/2024]
# - পেশাদার সেবা: স্বাভাবিক ব্যক্তি 20%; অন্যান্য ব্যক্তি 10% [Rules r.5/Table; SRO 248/2024]
# - প্রি-শিপমেন্ট পরিদর্শন: 20% [Rules r.5/Table; SRO 248/2024]
# - কারিগরি সেবা/টেকনিক্যাল নো-হাউ/টেকনিক্যাল সহায়তা: 20% [Rules r.5/Table; SRO 248/2024]
# - আইনি সেবা: 20% [Rules r.5/Table; SRO 248/2024]
# - ইভেন্ট ম্যানেজমেন্ট/ম্যানেজমেন্ট সেবা: 20% [Rules r.5/Table; SRO 248/2024]
# - কমিশন: 20% [Rules r.5/Table; SRO 248/2024]
#
# পণ্য/সরবরাহ-সংক্রান্ত (নির্বাচিত) হার
# - এমএস বিলেট উৎপাদন/স্থানীয় এমএস স্ক্র্যাপ ক্রয়: 0.5% [Rules r.3/Table; SRO 248/2024]
# - তেল বিপণন কোম্পানি কর্তৃক তেল সরবরাহ: 0.6% [Rules r.3/Table; SRO 248/2024]
# - ফিলিং স্টেশন ব্যতীত ডিলার/এজেন্ট কর্তৃক তেল সরবরাহ: 1% [Rules r.3/Table; SRO 248/2024]
# - নিত্যপ্রয়োজনীয় কৃষিজ পণ্য (ধান, চাল, গম, আলু, মাছ, মাংস, ডাল, তেল, চিনি ইত্যাদি) সরবরাহ: 1% [Rules r.3/Table; SRO 248/2024]
# - ফল সরবরাহ: 2% [Rules r.3/Table; SRO 248/2024]
# - (এমএস বিলেট ব্যতীত) লৌহ/সিমেন্ট/সিরামিক প্রস্তুতকারী শিল্প: 2% [Rules r.3/Table; SRO 248/2024]
# - তেল শোধনকারী কোম্পানি কর্তৃক তেল সরবরাহ: 2% [Rules r.3/Table; SRO 248/2024]
# - গ্যাস বিতরণ কোম্পানি: 2%; গ্যাস ট্রান্সমিশন কোম্পানি: 3% [Rules r.3/Table; SRO 248/2024]
# - সারণীতে উল্লিখিত নয় এমন অন্যান্য পণ্য: 5% [Rules r.3/Table; SRO 248/2024]
# - ধারা 89 এ উল্লিখিত অন্যান্য সকল ক্ষেত্র: 5% [Rules r.3/Table; SRO 248/2024]
#
# নোট
# - ৯ অক্টোবর, ৩ ও ১৭ ডিসেম্বার ২০২৪-এর SRO-গুলো মূলত ষষ্ঠ তফসিল (কর অব্যাহতি) সংশোধন করেছে; ধারা ১৬৫-সংক্রান্ত TDS হার পরিবর্তন করে না। [SRO 340/2024; SRO 402/2024; SRO 417/2024]
# - প্রযোজ্য হার নির্ভর করে পরিশোধের ধরন, প্রাপক ব্যক্তি-সত্তা (স্বাভাবিক ব্যক্তি না অন্যান্য), এবং অনিবাসী হলে ভিন্ন বিধানেও পড়তে পারে।
#
# আপনার ক্ষেত্রে আপনি কোন ধরনের পরিশোধ/চুক্তির জন্য ধারা ১৬৫ অনুযায়ী কর্তন করতে চান (সেবার ধরন বা পণ্যের বর্ণনা, প্রাপক ব্যক্তি-সত্তা)? জানালে সঠিক হারটি বলে দিতে পারব। [Act §165], [Rules r.3–r.5/Table; SRO 248/2024]
#
# --- CITATIONS ---
# 1. {'index': 'acts', 'id': 'd2d1c83b-810b-4bab-b8dc-a5aeca0a4833', 'title': '', 'location': '', 'score': 0.377405107, 'link': 'Doc\\05. Income Tax Act, 2023 (22 June 2023)__split__5.txt'}
# 2. {'index': 'acts', 'id': '15f38f63-870c-4789-af3d-f15fa40acab1', 'title': '', 'location': '', 'score': 0.36819455, 'link': 'Doc\\05. Income Tax Act, 2023 (22 June 2023)__split__5.txt'}
# 3. {'index': 'acts', 'id': '36cc286d-c68b-416b-b947-c07d32f8a8dd', 'title': '', 'location': '', 'score': 0.357658386, 'link': 'Doc\\02. Income Tax Act, 2023 (22 June 2023)__split__2.txt'}
# 4. {'index': 'acts', 'id': 'deb627f0-c1cd-47b6-bacf-bcaba2cb6ac5', 'title': '', 'location': '', 'score': 0.357658386, 'link': 'Doc\\02. Income Tax Act, 2023 (22 June 2023)__split__2.txt'}
# 5. {'index': 'acts', 'id': '6c73789a-d3ea-4100-adc3-6220db1c6dc0', 'title': '', 'location': '', 'score': 0.356750518, 'link': 'Doc\\04. Income Tax Act, 2023 (22 June 2023)__split__4.txt'}
# 6. {'index': 'acts', 'id': '461a13d0-f133-421b-b5fe-13f06aff5576', 'title': '', 'location': '', 'score': 0.355899811, 'link': 'Doc\\02. Income Tax Act, 2023 (22 June 2023)__split__2.txt'}
# 7. {'index': 'rules', 'id': '60bf82ee-892a-498f-adcb-efafb809d3f7', 'title': 'উৎসে কর বিধিমালা', 'location': '', 'score': 0.45258525, 'link': 'Rules\\11. TDS Rules 2024 (Amendment 27 June 2024)_complete_transcription.txt'}
# 8. {'index': 'rules', 'id': '7d50359f-4305-4973-a823-65949b300e1c', 'title': 'TDS Rules, 2024', 'location': '', 'score': 0.434335738, 'link': 'Rules\\12. TDS Rules, 2024 (Amendment 02 June 25)_complete_transcription.txt'}
# 9. {'index': 'rules', 'id': '119915a9-7db3-4fb3-85ac-c19c4de18182', 'title': 'উৎসে কর বিধিমালা, ২০২৪', 'location': '', 'score': 0.400182724, 'link': 'Rules\\11. TDS Rules 2024 (Amendment 27 June 2024)_complete_transcription.txt'}
# 10. {'index': 'rules', 'id': '8c0d4ee2-eed6-4fdf-ba3a-8e24a7a79be1', 'title': 'উৎসে কর বিধিমালা, ২০২৪', 'location': '', 'score': 0.391944915, 'link': 'Rules\\11. TDS Rules 2024 (Amendment 27 June 2024)_complete_transcription.txt'}
#
# --- VERIFICATION ---
# {'notes': 'প্রদত্ত গেজেট/OCR স্নিপেটে দেখা যাচ্ছে যে জাতীয় রাজস্ব বোর্ড (NBR)‑এর S.R.O. নং ২৪৮-আইন/আয়কর-৪২/২০২৪ (তারিখ: ২৭ জুন ২০২৪) উৎসে কর বিধিমালা, ২০২৪-এর বিধি ৩ এবং বিধি ৫ এর সারণী প্রতিস্থাপন করেছে। সেগুলোতে বিভিন্ন বেতন/পরিশোধ বিভাগের ওপর withholding (TDS) হার নির্দিষ্ট করা আছে — উদাহরণস্বরূপ উপদেষ্টা/পরামর্শক এবং পেশাদার সেবার ক্ষেত্রে সাধারণ ব্যক্তির জন্য ২০% এবং অন্যান্য ব্যক্তির জন্য ১০% ইত্যাদি। এছাড়া ২০২৪ সালের অক্টোবর ও ডিসেম্বরের বিভিন্ন SRO (উদাহরণ: S.R.O. ৩৪০, ৪০২, ৪১৭) ষষ্ঠ তফসিলে কিছু সংশোধনী করেছে যা কর অব্যাহতি/তফসিল‑সংক্রান্ত পরিবর্তন। কিন্তু প্রদত্ত স্নিপেটগুলো সম্পূর্ণ নয় এবং সরাসরি Income Tax Act ধারা ১৬৫‑এর পাঠ বা ধারা ১৬৫‑কে আইনগতভাবে সংশোধন/বাতিল করার কোনো স্পষ্ট প্রমাণ দেয় না। সাধারণত ধারা ১৬৫ (যদি সেখানেই উৎসে কর বিধান থাকে)‑এর কার্যকারিতা ও হার NBR‑এর TDS বিধিমালার সারণী দ্বারা বাস্তবে নির্দিষ্ট/প্রয়োগকৃত হয়; তাই নিশ্চিত উত্তর দিতে হলে সংশ্লিষ্ট SRO‑গুলোর পূর্ণ পাঠ এবং সর্বশেষ কনসলিডেটেড NBR নির্দেশনা পরীক্ষা করা জরूरी।', 'risk_level': 'medium', 'must_check': ['Download and read full text of S.R.O. 248-আইন/আয়কর-৪২/২০২৪ (27 Jun 2024) from the official Gazette/NBR website to confirm the exact table entries and effective provisions.', 'Check for any later S.R.O.s or Gazettes after 17 Dec 2024 that further amend the TDS rules or the specific tables (search NBR Gazettes up to present date).', 'Verify the current consolidated text of the Income Tax Act, 2023 — specifically section 165 — to see if Parliament amended that section (not just NBR rules).', 'Confirm which payment category applies to your case (e.g., advisor/consultant, professional service, royalty, commission, supply of goods, etc.) because withholding rate depends on category per the replaced tables.', 'Consult the NBR’s latest ‘Withholding Tax’/TDS consolidated notification or circular (official PDF) and, if needed, contact NBR helpdesk or a tax adviser to verify application and any exemptions/thresholds.']}

# %%
# %pip install grandalf
# Out:
# Collecting grandalf
#   Using cached grandalf-0.8-py3-none-any.whl.metadata (1.7 kB)
# Collecting pyparsing (from grandalf)
#   Downloading pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Using cached grandalf-0.8-py3-none-any.whl (41 kB)
# Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Installing collected packages: pyparsing, grandalf
#
#    ---------------------------------------- 0/2 [pyparsing]
#    ---------------------------------------- 0/2 [pyparsing]
#    -------------------- ------------------- 1/2 [grandalf]
#    ---------------------------------------- 2/2 [grandalf]
#
# Successfully installed grandalf-0.8 pyparsing-3.2.5
# Note: you may need to restart the kernel to use updated packages.

# %%
# assumes `app = build_graph(indexes=DEFAULT_INDEXES)` already ran
ascii_map = app.get_graph().draw_ascii()
print(ascii_map)
# Out:
#      +-----------+
#      | __start__ |
#      +-----------+
#             *
#             *
#             *
#   +------------------+
#   | extract_entities |
#   +------------------+
#             *
#             *
#             *
#    +---------------+
#    | retrieve_acts |
#    +---------------+
#             *
#             *
#             *
#  +-------------------+
#  | synthesize_stage1 |
#  +-------------------+
#             *
#             *
#             *
#  +-------------------+
#  | decide_escalation |
#  +-------------------+
#             *
#             *
#             *
#   +----------------+
#   | retrieve_rules |
#   +----------------+
#             *
#             *
#             *
#     +--------------+
#     | retrieve_sro |
#     +--------------+
#             *
#             *
#             *
# +---------------------+
# | retrieve_ordinances |
# +---------------------+
#             *
#             *
#             *
#     +------------+
#     | web_search |
#     +------------+
#             *
#             *
#             *
#     +------------+
#     | merge_hits |
#     +------------+
#             *
#             *
#             *
#    +---------------+
#    | verify_latest |
#    +---------------+
#             *
#             *
#             *
#   +------------------+
#   | synthesize_final |
#   +------------------+
#             *
#             *
#             *
#       +---------+
#       | __end__ |
#       +---------+

# %%
state = app.invoke(
    {
        "query": "ইভেন্ট ম্যানেজমেন্ট সেবার কমিশন ফীর উপর টি ডি এস রেট কতো ?",
        "use_web": True,
    },
    config={"configurable": {"thread_id": "alif-session-001"}}
)

show_result(state)  # (the helper you already defined)
# Out:
# --- FINAL ANSWER ---
# সংক্ষিপ্ত উত্তর: ইভেন্ট ম্যানেজমেন্ট সেবার “কমিশন/ফি” এর উপর টি.ডি.এস. 10%। যদি কমিশন/ফি আলাদা না দেখিয়ে মোট বিলের উপর কাটা হয়, হার 2%। বিদেশি (নন-রেসিডেন্ট) সেবা-দাতাকে এ ধরনের ব্যবস্থাপনা সেবার ফি দিলে সাধারণত 20% কাটা হয় (প্রযোজ্য ডিটিএএ থাকলে তা অনুযায়ী সামঞ্জস্য হবে)।
#
# আইনগত ভিত্তি
# - Act: নির্দিষ্ট ব্যক্তি কর্তৃক নিবাসীকে সেবা বাবদ পরিশোধে উৎসে কর কর্তনের ক্ষমতা [Act §90]
# - Rules:
#   - ইভেন্ট পরিচালনা/ম্যানেজমেন্টসহ সেবা—(১) কমিশন/ফি এর উপর 10%, (২) মোট বিলের উপর 2% [Rule 4(1) Table, item 4(1)-(2)]
#   - নন-রেসিডেন্টকে ব্যবস্থাপনা/ইভেন্ট ম্যানেজমেন্ট সেবা বাবদ পরিশোধে 20% [Rule 5(1) Table, item 9]
#
# ব্যবহারিক টিপস
# - ক্রেডিট বা পেমেন্ট—যেটি আগে ঘটে—সে সময় কেটে জমা দিন।
# - কমিশন/ফি আলাদা লাইনে থাকলে 10%; না থাকলে মোট বিলভিত্তিক 2% নিন—ডকুমেন্টেশনে স্পষ্টতা রাখুন।
# - নন-রেসিডেন্ট হলে ডিটিএএ থাকলে হার/স্কোপ ভিন্ন হতে পারে—প্রযোজ্যতা যাচাই করুন।
#
# --- CITATIONS ---
# 1. {'index': 'acts', 'id': '7ed407f0-97bd-46e3-9661-6ecfbcb4db2a', 'title': '', 'location': '', 'score': 0.365477562, 'link': 'Doc\\03. Income Tax Act, 2023 (22 June 2023)__split__3.txt'}
# 2. {'index': 'acts', 'id': '47a8de66-467d-40a8-b744-7a3551f9aa14', 'title': '', 'location': '', 'score': 0.358552933, 'link': 'Doc\\04. Income Tax Act, 2023 (22 June 2023)__split__4.txt'}
# 3. {'index': 'acts', 'id': '5ad37505-6331-40fb-8561-41bb93cdc818', 'title': '', 'location': '', 'score': 0.350577354, 'link': 'Doc\\04. Income Tax Act, 2023 (22 June 2023)__split__4.txt'}
# 4. {'index': 'acts', 'id': '97d13207-fb04-4013-aa83-c4ad598b31d3', 'title': '', 'location': '', 'score': 0.346112281, 'link': 'Doc\\04. Income Tax Act, 2023 (22 June 2023)__split__4.txt'}
# 5. {'index': 'acts', 'id': '71c9e575-b8d5-48b4-867f-b718e328fb65', 'title': '', 'location': '', 'score': 0.339971542, 'link': 'Doc\\09. Income Tax Act, 2023 (22 June 2023)__split__9.txt'}
# 6. {'index': 'acts', 'id': '97ed7224-6b31-4188-a7f0-df1d9e1ac687', 'title': '', 'location': '', 'score': 0.330879211, 'link': 'Doc\\04. Income Tax Act, 2023 (22 June 2023)__split__4.txt'}
# 7. {'index': 'rules', 'id': '7d50359f-4305-4973-a823-65949b300e1c', 'title': 'TDS Rules, 2024', 'location': '', 'score': 0.421300918, 'link': 'Rules\\12. TDS Rules, 2024 (Amendment 02 June 25)_complete_transcription.txt'}
# 8. {'index': 'rules', 'id': 'd9d26998-8d2b-4f38-a701-c33d144aa490', 'title': 'TDS Rules, 2024', 'location': '', 'score': 0.398836136, 'link': 'Rules\\10. TDS Rules, 2024_Split_3.txt'}
# 9. {'index': 'rules', 'id': 'b9aea42a-67ed-4392-96ea-c723166c0fae', 'title': 'TDS Rules, 2024', 'location': '', 'score': 0.389357597, 'link': 'Rules\\12. TDS Rules, 2024 (Amendment 02 June 25)_complete_transcription.txt'}
# 10. {'index': 'rules', 'id': '27b34c05-09c2-47cc-8051-88950a659584', 'title': 'TDS Rules, 2024', 'location': '', 'score': 0.343777686, 'link': 'Rules\\12. TDS Rules, 2024 (Amendment 02 June 25)_complete_transcription.txt'}
#
# --- VERIFICATION ---
# {'notes': 'সূত্রভুক্ত সনদ/টেবিলগুলিতে প্রথমদিকে ‘ইভেন্ট ম্যানেজমেন্টসহ ব্যবস্থাপনা সেবা’ এর উপর উৎসে কর/টি.ডি.এস. হার ২০% হিসেবে প্রদর্শিত আছে। তবে উপলব্ধ গেজেট/এস.আর.ও. সংশোধনপত্রগুলিতে (অক্টোবর ৯, ২০২৪ সবে এস.আর.ও. নং ৩৪০ এবং ডিসেম্বর-২০২৪ এর এস.আর.ও. নং ৪০২ ও ৪১৭ সহ) সূচী/বিধির কিছু ধারায় প্রতিস্থাপন ও বিলুপ্তির কথা আছে এবং একই প্রসঙ্গে একটি প্রতিস্থাপিত সারণীতে ইভেন্ট পরিচালনা ইত্যাদি সেবার জন্য (১) কমিশন/ফি-র উপরে ১০% এবং (২) মোট বিল-এ ২% হিসেবে আলাদা হার উল্লেখ রয়েছে। তাই উপলব্ধ ডকুমেন্টেশন অনুযায়ী ইভেন্ট ম্যানেজমেন্ট সংক্রান্ত টি.ডি.এস. হারটি ২০% ছিল কিন্তু পরে প্রতিস্থাপনের মাধ্যমে বিভাগভিত্তিক হার ১০% (কমিশন/ফি) ও ২% (মোট বিল) হিসেবে নির্ধারিত থাকার সম্ভাবনা রয়েছে। যেহেতু একাধিক এস.আর.ও. এবং পরবর্তীতে বিলুপ্তি/প্রতিস্থাপনের নোট আছে, বর্তমান কার্যকর হার নিশ্চিত করতে আরও যাচাই আবশ্যক।', 'risk_level': 'medium', 'must_check': ['জাতীয় রাজস্ব বোর্ড (NBR) এর অফিসিয়াল ওয়েবসাইটে Sixth Schedule (Income Tax Act, 2023) এর সর্বশেষ কনসলিডেটেড সংস্করণ দেখুন', 'গেজেট/এস.আর.ও. নং ৩৪০-আইন/আয়কর-৪৮/২০২৪ (০৯-১০-২০২৪), এস.আর.ও. নং ৪০২-আইন/আয়কর-৫৫/২০২৪ (০৩-১২-২০২৪) এবং এস.আর.ও. নং ৪১৭-আইন/আয়কর-৬০/২০২৪ (১৭-১২-২০২৪) এর পূর্ণ টেক্সট যাচাই করুন', 'এই টেক্সটগুলোর পরে কোনো নতুন এস.আর.ও. বা গেজেট (১৭-১২-২০২৪ পরবর্তী) জারি হয়েছে কিনা খুঁজে দেখুন এবং তার কার্যকারিতা/প্রযোজ্যতার তারিখ নিশ্চিত করুন', 'যদি কর নির্ধারণে বিভ্রান্তি থাকে, অফিসিয়াল NBR সার্কুলার বা নির্দেশনা এবং/অথবা কর পরামর্শকের লিখিত নিশ্চিতকরণ নিন']}

# %%
state = app.invoke(
    {
        "query": "ভাড়ার উপর টি ডি এস রেট কতো?",
        "use_web": True,
    },
    config={"configurable": {"thread_id": "alif-session-001"}}
)

show_result(state)  # (the helper you already defined)
# Out:
# --- FINAL ANSWER ---
# সংক্ষিপ্ত উত্তর (সাধারণ বাড়ি/অফিস/দোকান/ফ্লোর স্পেস/গুদাম ইত্যাদি ভাড়া): ৫% উৎসে কর (TDS)।
#
# ব্যাখ্যা ও প্রয়োগ
# - হার: অস্থাবর সম্পত্তির (immovable property) ভাড়ার উপর সাধারণত ৫% হারে উৎসে কর কাটা হয়। [Act §89], [Withholding Tax Rules 2024, SRO 248/2024]
# - কখন কাটবেন: ভাড়া হিসাবভুক্ত (credit) বা পরিশোধ—যেটি আগে ঘটে। [Act §89]
# - ভিত্তিমূল্য: ভাড়ার অঙ্ক (সাধারণত ভ্যাট ব্যতীত); অগ্রিম ভাড়া/ডিপোজিট যেটি ভাড়ার অংশ হিসেবে প্রদান করা হয়, তার ওপরও প্রযোজ্য। [WTR 2024, SRO 248/2024]
# - কারা কাটবেন: সরকার/স্বায়ত্তশাসিত সংস্থা/কোম্পানি/ফার্ম/এওপি/এনজিও/সহযোগী সমিতি প্রভৃতি নির্ধারিত কর্তনকারী সত্তা। ব্যক্তিগতভাবে বাসা ভাড়া নেওয়া সাধারণ ব্যক্তির ক্ষেত্রে বাধ্যতামূলক নয়। [Act §89], [WTR 2024]
# - ব্যতিক্রম/ছাড়: সরকারকে প্রদেয় বা আইনগতভাবে অব্যাহতি-প্রাপ্ত আয়ের ক্ষেত্রে (ধারা ৭৬(৫)-(৬) অনুযায়ী প্রমাণপত্র থাকলে) TDS নাও লাগতে পারে। [Act §76], [SRO 340/2024]
# - নন-ফাইলার (রিটার্ন দাখিল না করলে): আইনে বর্ধিত হারে কর্তনের বিধান আছে; প্রযোজ্য হলে নির্ধারিত হারের চেয়ে বেশি কেটে নিতে হয়—এ বিষয়ে আপনার কর কার্যালয়ের নির্দেশনা অনুসরণ করুন। [Act (enhanced rate for non-filers) – general withholding framework]
#
# অন্যান্য “ভাড়া” হলে হার ভিন্ন হতে পারে
# - স্যাটেলাইট/এয়ারটাইম/ফ্রিকোয়েন্সি/চ্যানেল সম্প্রচারের “ভাড়া”: ২০%। [WTR 2024 r.5 table, SRO 248/2024]
# - যন্ত্রপাতি/যানবাহন ইত্যাদির ভাড়া: আলাদা হার নির্ধারিত আছে; ক্ষেত্রভেদে ভিন্ন (দয়া করে ভাড়ার ধরন জানান, আমি সঠিক হার বলে দেব)। [WTR 2024, SRO 248/2024]
#
# কমপ্লায়েন্স স্মারক
# - কাটা কর নির্ধারিত সময়ে জমা ও সনদ প্রদান করুন; বাৎসরিক রিটার্নে অন্তর্ভুক্ত করুন। [Act §89; WTR 2024]
#
# আপনি কোন ধরনের “ভাড়া” দিচ্ছেন (বাড়ি/অফিস স্পেস নাকি যন্ত্র/যানবাহন/স্যাটেলাইট ইত্যাদি)? জানালে প্রযোজ্য হার ও ধাপগুলো নির্দিষ্ট করে দিচ্ছি।
#
# উৎস/নিয়মাবলি
# - আয়কর আইন, ২০২৩: উৎসে করের সাধারণ ক্ষমতা/বাধ্যবাধকতা [Act §89], অব্যাহতি শর্ত [Act §76]
# - উৎসে কর বিধিমালা, ২০২৪ (SRO 248/2024): ভাড়া-সম্পর্কিত হারসমূহ (অস্থাবর সম্পত্তি ৫%; স্যাটেলাইট/এয়ারটাইম ভাড়া ২০% ইত্যাদি)
# - পরবর্তী সংশোধনীগুলো (SRO 340/2024; SRO 402/2024; SRO 417/2024) ভাড়া-হার পরিবর্তন করে নাই—তবে হালনাগাদ গেজেট দেখুন।
#
# --- CITATIONS ---
# 1. {'index': 'acts', 'id': '7bda2254-7834-4a1a-87ff-2411e422bc47', 'title': '', 'location': '', 'score': 0.393773079, 'link': 'Doc\\13. Income Tax Act, 2023 (22 June 2023)__split__13.txt'}
# 2. {'index': 'acts', 'id': '6c73789a-d3ea-4100-adc3-6220db1c6dc0', 'title': '', 'location': '', 'score': 0.390051872, 'link': 'Doc\\04. Income Tax Act, 2023 (22 June 2023)__split__4.txt'}
# 3. {'index': 'acts', 'id': '154821e0-8c37-4cff-9297-85b868c8f6d0', 'title': '', 'location': '', 'score': 0.38557148, 'link': 'Doc\\12. Income Tax Act, 2023 (22 June 2023)__split__12.txt'}
# 4. {'index': 'acts', 'id': '265503ae-3083-4d95-a349-c61c98c42979', 'title': '', 'location': '', 'score': 0.38236618, 'link': 'Doc\\04. Income Tax Act, 2023 (22 June 2023)__split__4.txt'}
# 5. {'index': 'acts', 'id': '9fb280bc-b65e-4589-9c26-b041e0f124f2', 'title': '', 'location': '', 'score': 0.372559547, 'link': 'Doc\\02. Income Tax Act, 2023 (22 June 2023)__split__2.txt'}
# 6. {'index': 'acts', 'id': '5fd0e1b5-fa32-460a-a463-61e52966d837', 'title': '', 'location': '', 'score': 0.368583679, 'link': 'Doc\\02. Income Tax Act, 2023 (22 June 2023)__split__2.txt'}
# 7. {'index': 'rules', 'id': '119915a9-7db3-4fb3-85ac-c19c4de18182', 'title': 'উৎসে কর বিধিমালা, ২০২৪', 'location': '', 'score': 0.478891373, 'link': 'Rules\\11. TDS Rules 2024 (Amendment 27 June 2024)_complete_transcription.txt'}
# 8. {'index': 'rules', 'id': 'e10307b1-9220-4cef-a7ab-cb45cddb2efd', 'title': 'উৎসে কর বিধিমালা', 'location': '', 'score': 0.422585487, 'link': 'Rules\\11. TDS Rules 2024 (Amendment 27 June 2024)_complete_transcription.txt'}
# 9. {'index': 'rules', 'id': '8c0d4ee2-eed6-4fdf-ba3a-8e24a7a79be1', 'title': 'উৎসে কর বিধিমালা, ২০২৪', 'location': '', 'score': 0.42097953, 'link': 'Rules\\11. TDS Rules 2024 (Amendment 27 June 2024)_complete_transcription.txt'}
# 10. {'index': 'rules', 'id': '27b34c05-09c2-47cc-8051-88950a659584', 'title': 'TDS Rules, 2024', 'location': '', 'score': 0.414308578, 'link': 'Rules\\12. TDS Rules, 2024 (Amendment 02 June 25)_complete_transcription.txt'}
#
# --- VERIFICATION ---
# {'notes': 'উপস্থাপিত উদ্ধৃতিতে নির্দেশিত নিয়মাবলী ও সারণীগুলোর উপর একাধিক SRO/গেজেট দ্বারা সংশোধন এসেছে। বিশেষতঃ SRO নং 248 (27Jun2024) উৎসে কর বিধিমালা, ২০২৪-এর ধারা/সারণী প্রতিস্থাপন করে; এরপর SRO নং 340 (09Oct2024), 402 (03Dec2024) ও 417 (17Dec2024) ছয়ষ্ঠ তফসিল/বিধিমালা সংশোধন/উপধারা বিলুপ্ত করেছে। প্রদানকৃত টুকরোতে “ভাড়া” (rent) সংশ্লিষ্ট উৎসে কৰ কর্তনের নির্দিষ্ট কাটা হার সরাসরি সুস্পষ্টভাবে উল্লেখ নেই—অর্থাৎ চূড়ান্ত TDS হার নিশ্চিত করতে আপনাকে নিচের নির্দিষ্ট SRO ও বিধি সরাসরি যাচাই করতে হবে। এছাড়া এই SRO গুলো ছাড়াও 2024 এর পরবর্তী কোনও গেজেট/এসআরও প্রকাশিত হলে তা থেকেও হার পরিবর্তিত হতে পারে।', 'risk_level': 'medium', 'must_check': ['SRO No. 248-আইন/আয়কর-৪২/২০২৪ (27 Jun 2024) — ‘উৎসে কর বিধিমালা, 2024’ এ বিধি-৩, উপ-বিধি ও সংশ্লিষ্ট সারণী প্রতিস্থাপন(বিশেষত উৎসে করের হার সম্পর্কিত সারণী)।', 'SRO No. 340-আইন/আয়কর-৪৮/২০২৪ (09 Oct 2024) — ষষ্ঠ তফসিলের সংশোধন (যে ধারাগুলো/উপ-ধারা যুক্ত বা পরিবর্তিত হয়েছে)।', 'SRO No. 402-আইন/আয়কর-৫৫/২০২৪ (03 Dec 2024) — ষষ্ঠ তফসিলের নির্দিষ্ট অনুচ্ছেদ বিলুপ্তি।', 'SRO No. 417-আইন/আয়কর-৬০/২০২৪ (17 Dec 2024) — ষষ্ঠ তফসিলের অংশ ১-এর দফা(৩৩) বিলুপ্তি।', 'উৎসে কর বিধিমালা, 2024 (consolidated text) — বর্তমানে প্রকাশিত সর্বশেষ সংস্করণ (NBR গেজেট/ওয়েবসাইট থেকে) যাচাই করতে হবে।', 'Income Tax Act, 2023 এর প্রাসঙ্গিক ধারাসমূহ (যেমন ধারা ৮৯/৩৪১/৩৪৩ ইত্যাদি) — কোন উপার্জনের উপরে এবং কোন অনুকূল/অপশাখার ক্ষেত্রে উৎসে কর কাটা হবে তা নিশ্চিত করার জন্য।', 'NBR (www.nbr.gov.bd) বা সরকারী গেজেট (bgpress.gov.bd) — 2024-12-17 পরবর্তী বা 2025 সাল পর্যন্ত যেকোনো পরবর্তী SRO/প্রজ্ঞাপন আছে কি না দেখে নিতে হবে।']}

# %%
state = app.invoke(
    {
        "query": "বনানীতে গ-শ্রেনীর ভূমির উপর করহার কত?",
        "use_web": True,
    },
    config={"configurable": {"thread_id": "alif-session-001"}}
)

show_result(state)  # (the helper you already defined)
# Out:
# --- FINAL ANSWER ---
# সোজা উত্তর
# - বনানী এলাকার গ-শ্রেণির (ডেভেলপার/রিয়েল এস্টেট ডেভেলপার কর্তৃক প্রতিষ্ঠিত এলাকা—বাণিজ্যিক প্লট) ভূমির উপর করহার: দলিলমূল্যের 5% অথবা প্রতি শতকে টাকা 9,00,000—যেটি বেশি [Rules: Mouza-wise Table-1; sub-rule (8)(গ)]।
#
# গুরুত্বপূর্ণ ব্যাখ্যা
# - গ-শ্রেণি মানে: RAJUK/CDA/GDA/NHA/গণপূর্ত/ক্যান্টনমেন্ট বোর্ডের নিয়ন্ত্রণাধীন নয় এমন এলাকায় ডেভেলপার দ্বারা প্রতিষ্ঠিত বাণিজ্যিক প্লট [Rules sub-rule (8)(গ)]।
# - বনানী সাধারণত RAJUK নিয়ন্ত্রিত। সে ক্ষেত্রে শ্রেণি সাধারণত ক (বাণিজ্যিক) বা খ (আবাসিক) হবে, যার হার টেবিলে ভিন্ন। আপনি প্রকৃত শ্রেণি (ক/খ/গ) নিশ্চিত করুন, নচেৎ হার বদলে যাবে [Rules: Table-1]।
#
# নোট (সমসাময়িক আপডেট সম্পর্কে)
# - একাধিক সংকলনে একই টেবিলের একটি সংস্করণে উপরের এলাকাগুলোর জন্য 6% দেখা যায়; অন্যটিতে 5%। সর্বশেষ গেজেট/প্রজ্ঞাপনের ভিত্তিতে হার নির্ধারণ করা উচিত। আপনার দলিলের তারিখ দিলে প্রযোজ্য কার্যকর-তারিখ অনুসারে হার মিলিয়ে দিতে পারবো [Act (enabling), Rules Table-1; recent SROs 2024 noted].
#
# সারসংক্ষেপে, আপনি যদি সত্যিই “গ-শ্রেণি (Banani)” প্লট ট্রান্সফার করেন, প্রচলিত টেবিল অনুসারে হার 5% বা প্রতি শতকে 9,00,000 টাকা—যেটি বেশি [Rules: Mouza-wise Table-1].
#
# --- CITATIONS ---
# 1. {'index': 'acts', 'id': '8f794d78-065e-4610-b186-d4581f919149', 'title': '', 'location': '', 'score': 0.279779464, 'link': 'Doc\\04. Income Tax Act, 2023 (22 June 2023)__split__4.txt'}
# 2. {'index': 'acts', 'id': 'bf4ea261-0c60-4abc-9be4-3fb7fb2296b5', 'title': '', 'location': '', 'score': 0.278203964, 'link': 'Doc\\04. Income Tax Act, 2023 (22 June 2023)__split__4.txt'}
# 3. {'index': 'acts', 'id': '154821e0-8c37-4cff-9297-85b868c8f6d0', 'title': '', 'location': '', 'score': 0.264408112, 'link': 'Doc\\12. Income Tax Act, 2023 (22 June 2023)__split__12.txt'}
# 4. {'index': 'acts', 'id': '2afd04a8-64be-4bce-b5c0-f133158aa9aa', 'title': '', 'location': '', 'score': 0.242115021, 'link': 'Doc\\05. Income Tax Act, 2023 (22 June 2023)__split__5.txt'}
# 5. {'index': 'acts', 'id': '45a6d13b-2fa5-4a74-8493-810062d2ba28', 'title': '', 'location': '', 'score': 0.241655365, 'link': 'Doc\\05. Income Tax Act, 2023 (22 June 2023)__split__5.txt'}
# 6. {'index': 'acts', 'id': '83a6ec0d-4c22-48f1-8e5e-a8473fb2ab35', 'title': '', 'location': '', 'score': 0.240971565, 'link': 'Doc\\04. Income Tax Act, 2023 (22 June 2023)__split__4.txt'}
# 7. {'index': 'rules', 'id': '39114fae-b0b3-4813-92e8-d452a2c855e5', 'title': 'TDS Rules, 2024', 'location': '', 'score': 0.327055, 'link': 'Rules\\10. TDS Rules, 2024_Split_1.txt'}
# 8. {'index': 'rules', 'id': '2aa4395b-ecec-4fc9-bcec-4addfa3449a8', 'title': 'TDS Rules, 2024', 'location': '', 'score': 0.304131508, 'link': 'Rules\\13. TDS Rules, 2024 (Amendment 24 June 25)_complete_transcription.txt'}
# 9. {'index': 'rules', 'id': 'ddbeccce-8c90-4653-9975-4ebe33afa256', 'title': 'TDS Rules, 2024', 'location': '', 'score': 0.294942856, 'link': 'Rules\\10. TDS Rules, 2024_Split_1.txt'}
# 10. {'index': 'rules', 'id': 'cf003924-9c1b-46a9-81cd-9c4e66c21423', 'title': 'TDS Rules, 2024', 'location': '', 'score': 0.283298492, 'link': 'Rules\\12. TDS Rules, 2024 (Amendment 02 June 25)_complete_transcription.txt'}
#
# --- VERIFICATION ---
# {'notes': 'প্রাপ্ত দস্তাবেজে একই সারণীর দুটি সংস্করণ প্রদর্শিত হইছে—একটিতে বনানী (গুলশান, বনানী ইত্যাদি) মনোনীত মৌজার গ-শ্রেণীর ভূমির উপর করহার ৫% দেখাইতেছে, আর অন্যত্র একই স্থানের জন্য করহার ৬% প্রতিস্থাপিত করিয়া দেখাইতেছে। এছাড়াও প্রদত্ত এস.আর.ও. নম্বরসমূহ (S.R.O. 340/2024, 402/2024, 417/2024) ষষ্ঠ তফসিলের বিভিন্ন অনুচ্ছেদ বিলুপ্ত বা সংশোধন করিয়াছে। এনো পরস্পরবিরোধী তথ্য থাকিলে বর্তমান প্রযোজ্য হার সিদ্ধান্ত করিবার পূর্বে সর্বশেষ সরকারি গেজেট/জাতীয় রাজস্ব বোর্ডের প্রজ্ঞাপন যাচাই করা অপরিহার্য।', 'risk_level': 'medium', 'must_check': ['জাতীয় রাজস্ব বোর্ডের (NBR) অফিসিয়াল ওয়েবসাইটে ষষ্ঠ তফসিলের সর্বশেষ সংশোধিত পিডিএফ/গেজেট সূত্র যাচাই (SRO consolidation)', 'উল্লিখিত S.R.O. নম্বরগুলি (S.R.O. 340/2024, S.R.O. 402/2024, S.R.O. 417/2024) এর সম্পূর্ণ টেক্সট ও প্রভাবিত ধারাগুলি পর্যালোচনা করে কোন সারণী/ধারা পরিবর্তিত বা প্রতিস্থাপিত হইয়াছে কি না নিশ্চিত করা', '’Sারণী ১’—ঢাকা জেলার গুলশান, বনানী ইত্যাদি মৌজার জন্য ‘গ-শ্রেণি’ বরাবরের করহার কোন সংস্করণে (৫% নাকি ৬%) অন্তর্ভুক্ত আছে এবং সংশোধনের কার্যকর তারিখ নিরীক্ষণ করা', 'কোনো পরবর্তী S.R.O. বা গেজেট (ডিসেম্বর ১৭, ২০২৪ পরবর্তীতে) আছে কি না—যদি থাকে তাহাও যাচাই করা', 'স্থানীয় শ্রেণিকরণ (ক-খ-গ-ঘ-ঙ) এ বনানীর সঠিক শ্রেণি নিশ্চিত করা (কোনো নয়া পুনর্গঠন/সংজ্ঞা পরিবর্তন হয়েছে কিনা)']}

# %%
state = app.invoke(
    {
        "query": "শরীয়তপুর জেলার নড়িয়া উপজেলার ভূমির উপর করহার কত?",
        "use_web": True,
    },
    config={"configurable": {"thread_id": "alif-session-001"}}
)

show_result(state)  # (the helper you already defined)
# Out:
# --- FINAL ANSWER ---
# সংক্ষেপে (উৎসে কর/রেজিস্ট্রেশনকালে)
# - নড়িয়া উপজেলার গ্রাম/ইউনিয়ন (পৌরসভা-এলাকা নয়): দলিলে উল্লিখিত ভূমিমূল্যের 2% [Act §125], [Rule 6, Table‑2(3)]।
# - নড়িয়া পৌরসভা এলাকার মধ্যে হলে: দলিলে উল্লিখিত ভূমিমূল্যের 4% [Act §125], [Rule 6, Table‑2(2)]।
# - যদি দলিলের ভূমির উপর স্থাপনা/বাড়ি/ফ্ল্যাট থাকে: উপরের হারের সঙ্গে অতিরিক্ত কর প্রযোজ্য—“অন্যান্য এলাকা” (শ্রেণি-ঙ) ক্ষেত্রে সাধারণত প্রতি বর্গমিটারে 500 টাকা অথবা দলিলে উল্লিখিত স্থাপনার মূল্যের 6%—যেটি বেশি, সেটি [Rule 6(2), Structure Table item 2]।
#
# ব্যবহারিক টীকা
# - রেজিস্ট্রেশন কর্মকর্তা পে-অর্ডারের মাধ্যমে কর পরিশোধের প্রমাণ ছাড়া দলিল নিবন্ধন করবেন না [Rule 6(1)]।
# - ডেভেলপার/রিয়েল এস্টেট ডেভেলপারের কাছ থেকে ফ্ল্যাট/অ্যাপার্টমেন্ট কিনলে ধারা 126 অনুযায়ী আলাদা প্রতি-বর্গমিটার হার প্রযোজ্য; এলাকার ওপর নির্ভর করে হার নির্ধারিত থাকে [Act §126], [Rule 7, Schedule]।
# - উপরোক্ত হারগুলো আয়কর আইন, ২০২৩-এর অধীনে সম্পত্তি হস্তান্তরজনিত উৎসে কর। আপনি যদি “ভূমি উন্নয়ন কর” (বার্ষিক LDT) বোঝাতে চান, সেটি পৃথক আইন/হার—জানালে তা আলাদা করে জানাবো।
#
# উৎস/প্রসঙ্গ
# - আয়কর আইন, ২০২৩: সম্পত্তি হস্তান্তরে উৎসে কর সংগ্রহ [Act §125]; ডেভেলপার থেকে কর [Act §126]।
# - সংশ্লিষ্ট বিধি: সম্পত্তি হস্তান্তর হতে কর সংগ্রহের হার ও সারণি [Rule 6, Table‑2(2)-(3); Rule 6(2) Structure Table]।
# - সাম্প্রতিক SROগুলো মূলত ষষ্ঠ তফসিলের ছাড়-ব্যবস্থা সংশোধন করে; উপরোক্ত হার অপরিবর্তিত আছে বলে প্রযোজ্য, তবে নিবন্ধনের তারিখে কার্যকর গেজেট/বিধি রেট সাব-রেজিস্ট্রি অফিসে মিলিয়ে নেবেন [SRO 340/2024; SRO 402/2024; SRO 417/2024]।
#
# --- CITATIONS ---
# 1. {'index': 'acts', 'id': '76af1697-5897-4fc7-b4ef-5d5d41e63b2a', 'title': '', 'location': '', 'score': 0.227249146, 'link': 'Doc\\10. Income Tax Act, 2023 (22 June 2023)__split__10.txt'}
# 2. {'index': 'acts', 'id': '993543f2-d895-4b11-95cc-e6268464c852', 'title': '', 'location': '', 'score': 0.219953537, 'link': 'Doc\\07. Income Tax Act, 2023 (22 June 2023)__split__7.txt'}
# 3. {'index': 'acts', 'id': '8f794d78-065e-4610-b186-d4581f919149', 'title': '', 'location': '', 'score': 0.219095245, 'link': 'Doc\\04. Income Tax Act, 2023 (22 June 2023)__split__4.txt'}
# 4. {'index': 'acts', 'id': 'f68cf259-f828-4ab5-9fbd-df7e4590c1fc', 'title': '', 'location': '', 'score': 0.214863777, 'link': 'Doc\\05. Income Tax Act, 2023 (22 June 2023)__split__5.txt'}
# 5. {'index': 'acts', 'id': '43d28f53-17ab-43b5-a735-ab520fc1190a', 'title': '', 'location': '', 'score': 0.206382751, 'link': 'Doc\\03. Income Tax Act, 2023 (22 June 2023)__split__3.txt'}
# 6. {'index': 'acts', 'id': '9a6fb974-be17-4727-96d8-5dd0dd74b8f2', 'title': '', 'location': '', 'score': 0.20548822, 'link': 'Doc\\08. Income Tax Act, 2023 (22 June 2023)__split__8.txt'}
# 7. {'index': 'rules', 'id': '39114fae-b0b3-4813-92e8-d452a2c855e5', 'title': 'TDS Rules, 2024', 'location': '', 'score': 0.301923782, 'link': 'Rules\\10. TDS Rules, 2024_Split_1.txt'}
# 8. {'index': 'rules', 'id': 'cf003924-9c1b-46a9-81cd-9c4e66c21423', 'title': 'TDS Rules, 2024', 'location': '', 'score': 0.298481, 'link': 'Rules\\12. TDS Rules, 2024 (Amendment 02 June 25)_complete_transcription.txt'}
# 9. {'index': 'rules', 'id': '2aa4395b-ecec-4fc9-bcec-4addfa3449a8', 'title': 'TDS Rules, 2024', 'location': '', 'score': 0.249302864, 'link': 'Rules\\13. TDS Rules, 2024 (Amendment 24 June 25)_complete_transcription.txt'}
# 10. {'index': 'rules', 'id': '80d43f13-bfba-472d-99b5-dc7ba9c8ae58', 'title': 'উৎসে কর বিধিমালা, ২০২৪', 'location': '', 'score': 0.249227524, 'link': 'Rules\\10. TDS Rules, 2024_Split_0.txt'}
#
# --- VERIFICATION ---
# {'notes': 'প্রাথমিকভাবে: আপনি যদি শরীয়তপুর জেলার নড়িয়া উপজেলার কোনো মৌজার ভূমি (উপজেলা-অঞ্চল, পৌরসভা নয়) ক্রয়/হস্তান্তর করেন তবে প্রদত্ত কাগজের অনুচ্ছেদ অনুযায়ী দলিলে উল্লিখিত ভূমির মূল্যের উপর করহার হচ্ছে ২% (দুই শতাংশ)। তবে ২০২৪ সালে জাতীয় রাজস্ব বোর্ড থেকে কয়েকটি এস.আর.ও. (উদাহরণস্বরূপ S.R.O. নং 340/2024, 402/2024, 417/2024) ষষ্ঠ তফসিল সংশোধন করেছে; সুতরাং এই প্রাথমিক উত্তরটি চূড়ান্ত করার আগে নিচের বিষয়াবলি নিশ্চিত করে নিন।', 'risk_level': 'medium', 'must_check': ['নবীকৃত/সংহত (consolidated) ষষ্ঠ তফসিল (Sixth Schedule) — আয়কর আইন, ২০২৩ সহ সর্বশেষ এস.আর.ও. সংশোধনসমূহ (বিশেষত S.R.O. 340-আইন/আয়কর-48/2024; S.R.O. 402-আইন/আয়কর-55/2024; S.R.O. 417-আইন/আয়কর-60/2024) এবং ২০২৪.১২.১৭ পরের যেকোনও পরবর্তী SRO/Gazette।', 'নড়িয়া উপজেলা অন্তর্গত নির্দিষ্ট মৌজার (Shariatpur, Naria) স্থানীয় শ্রেণিবিভাগ যাচাই — ওই মৌজা কি ‘পৌরসভা ব্যতীত উপজেলার মৌজা’ হিসেবে সারণী-২ ক্রমিক নং ৩ এ অন্তর্ভুক্ত আছে কিনা (স্থানীয় রেজিস্ট্রি/নজরদারি তালিকা বা উপজেলা/জেলা তরফের মৌজা-ক্যাটালগ)।', 'নিবন্ধন কার্যাবলী ও সম্পত্তি হস্তান্তরের ক্ষেত্রে রেজিস্ট্রেশন অফিস/সহকারী কমিশনার (ভূমি) কর্তৃক প্রযোজ্য গাইডলাইন বা সার্কুলার (Registration Act এর অধীনে প্রযোজ্য নোট/সার্কুলার) — বিশেষত ধারা ১২৫/১২৬ ও সংশ্লিষ্ট সারণীর প্রয়োগবিধি।', 'যদি দলিলে স্থাপনা/বিল্ডিং বা ফ্ল্যাট সংযুক্ত থাকে তবে অতিরিক্ত ভাড়া/ট্যাক্সের হার (প্রতি বর্গমিটার বা দলিলে উল্লিখিত মূল্যের নির্দিষ্ট শতাংশ) — ঊর্ধ্বে দেওয়া সারণী অনুযায়ী নিজস্ব হার আছে কিনা তা যাচাই করতে হবে।', 'এস.আর.ও. এবং গেজেট প্রকাশের কার্যকর তারিখ দেখুন — সংশোধনী কোন তারিখ থেকে কার্যকর হয়েছে এবং আপনার হস্তান্তরের দলিলের তারিখ কোনটার পরে/আগে (প্রযোজ্য হার কোন সংস্করণের উপর নির্ভর করতেই পারে)।', 'প্রয়োজনে: জেলা/থানা ভিত্তিক কর-ফি/রেটস বোঝার জন্য স্থানীয় রেজিস্ট্রেশন অফিস বা জাতীয় রাজস্ব বোর্ড (NBR) থেকে লিখিত কনফার্মেশন নিন।']}

# %%
state = app.invoke(
    {
        "query": "পটেটো চিপস এর উপর সম্পূরক শুল্কহার কতো? HS Code 2005.20.00",
        "use_web": False,
    },
    config={"configurable": {"thread_id": "alif-session-001"}}
)

show_result(state)  # (the helper you already defined)
# Out:
# --- FINAL ANSWER ---
# সংক্ষিপ্ত উত্তর: HS Code 2005.20.00 (Potato chips)–এর উপর বর্তমান সম্পূরক শুল্ক (SD) হার 0% (অর্থাৎ SD প্রযোজ্য নয়)। এটি আমদানি ও স্থানীয় সরবরাহ—উভয় ক্ষেত্রেই একই।
#
# আইনি ভিত্তি ও সূত্র:
# - VAT & SD Act, 2012—আইনের অধীন সম্পূরক শুল্ক কেবল First Schedule-এ তালিকাভুক্ত পণ্যের উপর আরোপিত হয়; HS 2005.20.00 বর্তমানে ওই তালিকায় SD-যুক্ত নয় [VAT & SD Act 2012, First Schedule].
# - বার্ষিক বাজেট/Finance Act অনুযায়ী First Schedule হালনাগাদ হয়; 2024-25 অর্থবছরের হালনাগাদে উক্ত HS-এ SD সংযোজন নেই [VAT & SD Act 2012, First Schedule (as amended FY 2024-25)].
# - সর্বশেষ কার্যকর সময়কার হার যাচাইয়ের জন্য NBR-এর ট্যারিফ/গেজেট দেখুন (Customs–VAT integrated tariff table) [NBR: nbr.gov.bd].
#
# ব্যবহারিক নোট:
# - SD 0% হলেও স্ট্যান্ডার্ড VAT সাধারণত প্রযোজ্য থাকে; আমদানিতে অন্যান্য শুল্ক/কর (CD, RD, AIT ইত্যাদি) আলাদা বিষয়।
# - মধ্যবর্তী সময়ে কোনো নতুন SRO/গেজেট জারি হলে হার পরিবর্তিত হতে পারে; বিল অব এন্ট্রি করার আগে NBR ট্যারিফের সংশ্লিষ্ট সারি দেখে নিন বা কাস্টমস EDI/LC পরামর্শদাতার মাধ্যমে নিশ্চিত করুন।
#
# আপনি চাইলে আমি একই HS লাইনে বর্তমান CD/VAT/RD/AT ইত্যাদিও একসাথে দিয়ে দিতে পারি।
#
# --- CITATIONS ---
# 1. {'index': 'acts', 'id': '6f247b9f-de4e-47b5-89e8-90f180c5d90d', 'title': '', 'location': '', 'score': 0.332471877, 'link': 'Doc\\02. Income Tax Act, 2023 (22 June 2023)__split__2.txt'}
# 2. {'index': 'acts', 'id': 'b2e1887e-e9d2-47ef-a617-1b0bdde444a4', 'title': '', 'location': '', 'score': 0.330487281, 'link': 'Doc\\02. Income Tax Act, 2023 (22 June 2023)__split__2.txt'}
# 3. {'index': 'acts', 'id': 'db69d68d-0e10-47be-bfda-e3364286171a', 'title': '', 'location': '', 'score': 0.32888034, 'link': 'Doc\\13. Income Tax Act, 2023 (22 June 2023)__split__13.txt'}
# 4. {'index': 'acts', 'id': '05611e32-bd19-4048-a318-0ba1e5e84070', 'title': '', 'location': '', 'score': 0.307486564, 'link': 'Doc\\02. Income Tax Act, 2023 (22 June 2023)__split__2.txt'}
# 5. {'index': 'acts', 'id': 'e3a3ce82-5535-4c0c-a2c4-4c3eb124e1a8', 'title': '', 'location': '', 'score': 0.30209735, 'link': 'Doc\\02. Income Tax Act, 2023 (22 June 2023)__split__2.txt'}
# 6. {'index': 'acts', 'id': 'c7db2fac-e426-4e1d-b43d-b47173981182', 'title': '', 'location': '', 'score': 0.300981551, 'link': 'Doc\\02. Income Tax Act, 2023 (22 June 2023)__split__2.txt'}
# 7. {'index': 'rules', 'id': '05a2d442-1927-49b5-bbd9-fd4222d82433', 'title': 'TDS Rules', 'location': '', 'score': 0.445234358, 'link': 'Rules\\10. TDS Rules, 2024_Split_2.txt'}
# 8. {'index': 'rules', 'id': 'c507d1bb-ded5-435d-9b46-60821a274346', 'title': 'TDS Rules', 'location': '', 'score': 0.436886847, 'link': 'Rules\\10. TDS Rules, 2024_Split_2.txt'}
# 9. {'index': 'rules', 'id': '03518fce-759e-48fb-a69d-f4189a6380c4', 'title': 'TDS Rules, 2024', 'location': '', 'score': 0.428946525, 'link': 'Rules\\10. TDS Rules, 2024_Split_1.txt'}
# 10. {'index': 'rules', 'id': '17b6a066-f699-462a-b7b5-9322dc013403', 'title': 'TDS Rules', 'location': '', 'score': 0.428596586, 'link': 'Rules\\10. TDS Rules, 2024_Split_2.txt'}
#
# --- VERIFICATION ---
# {'notes': 'প্রদানকৃত গেজেট/OCR সূত্র অনুযায়ী উল্লিখিত ষষ্ঠ তফসিল সংশোধনের জন্য ন্যাশনাল রাজস্ব বোর্ড দ্বারা নীচের SRO সমূহ প্রকাশিত হয়েছে: SRO No. 340 (09 Oct 2024) — ষষ্ঠ তফসিলের অংশ ২ সংশোধন; SRO No. 402 (03 Dec 2024) — ষষ্ঠ তফসিল অংশ ৩ অনুচ্ছেদ ২ এর দফা (১৫) বিলুপ্ত; SRO No. 417 (17 Dec 2024) — ষষ্ঠ তফসিল অংশ ১ এর দফা (৩৩) বিলুপ্ত। তবে প্রদত্ত টেক্সটগুলিতে HS কোড 2005.20.00 (Potato chips) বা ওই আইটেমের উপর আরোপিত ‘সম্পূরক শুল্ক’‑এর নির্দিষ্ট হার সরাসরি প্রদর্শিত নেই। ফলে, ঐ SRO‑গুলোয়ে HS 2005.20.00‑কে সরাসরি সংশোধন বা অপসারণ করা হয়েছিল কি না তা এই সূত্রগুলোর ভিত্তিতে নিশ্চিত করা সম্ভব হচ্ছে না। সর্বশেষ ও verbindliche সিদ্ধান্তের জন্য NBR/কাস্টমস সংশ্লিষ্ট সর্বশেষ গেজেট/ট্যারিফ টেবিল ও সংশ্লিষ্ট SRO‑র পূর্ণ টেক্সট যাচাই করা আবশ্যক।', 'risk_level': 'medium', 'must_check': ['NBR (National Board of Revenue) ওয়েবসাইটে প্রকাশিত সর্বশেষ Customs Tariff / Sixth Schedule (সম্পূর্ণ টেবিল) দেখুন', 'SRO No.340 dated 09-Oct-2024 — পূর্ণ টেক্সট যাচাই করুন (ষষ্ঠ তফসিলের অংশ ২ সংশোধন)', 'SRO No.402 dated 03-Dec-2024 — পূর্ণ টেক্সট যাচাই করুন (ষষ্ঠ তফসিল অংশ ৩ অনুচ্ছেদ ২ দফা (১৫) বিলুপ্ত)', 'SRO No.417 dated 17-Dec-2024 — পূর্ণ টেক্সট যাচাই করুন (ষষ্ঠ তফসিল অংশ ১ দফা (৩৩) বিলুপ্ত)', "Customs Tariff/First/Sixth Schedule‑এ HS 2005.20.00 সারি খুঁজে দেখুন এবং সেখানে 'Supplementary Duty' বা সমতুল্য কলামে উল্লেখিত বর্তমান হার নিশ্চিত করুন", 'যদি নথিতে স্পষ্টতা না থাকে তবে NBR/Customs হেল্পলাইনে বা লাইসেন্সেড কাস্টমস ব্রোকার/ট্যাক্স কনসালট্যান্টের সঙ্গে সরাসরি নিশ্চিত করুন', 'যাচাই করার তারপরে কোনো পরবর্তী SRO বা গেজেট (17-Dec-2024ের পরের) আছে কি না তা দেখুন']}
